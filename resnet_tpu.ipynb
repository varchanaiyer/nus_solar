# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import os

pp_time=np.load(os.path.join('..', 'benchmark_results', 'models', 'ureshape_resnet_model_edgetpu', 'pp_time.npy'))
p_time=np.load(os.path.join('..', 'benchmark_results', 'models', 'ureshape_resnet_model_edgetpu', 'p_time.npy'))
t_time=np.load(os.path.join('..', 'benchmark_results', 'models', 'ureshape_resnet_model_edgetpu', 't_time.npy'))

print('-------------FOR EdgeTPU Dev Board---------')
print('-------------For Inference-------------')
print(f'Total Number of Images : {len(p_time)}')
print(f'Max Inference Time is : {round(np.max(p_time[1:]), 6)} msecs')
print(f'Min Inference Time is : {round(np.min(p_time[1:]), 6)} msecs')
print(f'Average Inference Time is : {round(np.average(p_time[1:]), 6)} msecs')
print(f'Mean Inference Time is : {round(np.mean(p_time[1:]), 6)} msecs')

plt.plot(p_time[1:])
plt.ylabel('Time in secs')
plt.xlabel('Iterations')
plt.show()
# Out:
# -------------FOR EdgeTPU Dev Board---------
# -------------For Inference-------------
# Total Number of Images : 100
# Max Inference Time is : 51.354465 msecs
# Min Inference Time is : 50.402863 msecs
# Average Inference Time is : 50.842236 msecs
# Mean Inference Time is : 50.842236 msecs

# %%
print('------------For Preprocessing----------')
print(f'Total Number of Images : {len(pp_time)}')
print(f'Max Preprocessing Time is : {round(np.max(pp_time[1:]), 6)} secs')
print(f'Min Preprocessing Time is : {round(np.min(pp_time[1:]), 6)} secs')
print(f'Average v Time is : {round(np.average(pp_time[1:]), 6)} secs')
print(f'Mean Preprocessing Time is : {round(np.mean(pp_time[1:]), 6)} secs')

plt.plot(pp_time)
plt.ylabel('Time in secs')
plt.xlabel('Iterations')
plt.show()
# Out:
# ------------For Preprocessing----------
# Total Number of Images : 100
# Max Preprocessing Time is : 0.298785 secs
# Min Preprocessing Time is : 0.265671 secs
# Average v Time is : 0.27791 secs
# Mean Preprocessing Time is : 0.27791 secs

# %%
print('----------Total Time-----------')
print(f'Total Number of Images : {len(t_time)}')
print(f'Max Time is : {round(np.max(t_time[1:]), 6)} msecs')
print(f'Min Time is : {round(np.min(t_time[1:]), 6)} secs')
print(f'Average Time is : {round(np.average(t_time[1:]), 6)} secs')
print(f'Average Time is : {round(np.mean(t_time[1:]), 6)} secs')

plt.plot(t_time)
plt.ylabel('Time in secs')
plt.xlabel('Iterations')
plt.show()
# Out:
# ----------Total Time-----------
# Total Number of Images : 100
# Max Time is : 0.350602 msecs
# Min Time is : 0.317884 secs
# Average Time is : 0.330067 secs
# Average Time is : 0.330067 secs

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import os

pp_time=np.load(os.path.join('..', 'benchmark_results', 'models', 'ureshape_resnet_model_edgetpu_accelerator', 'pp_time.npy'))
p_time=np.load(os.path.join('..', 'benchmark_results', 'models', 'ureshape_resnet_model_edgetpu_accelerator', 'p_time.npy'))
t_time=np.load(os.path.join('..', 'benchmark_results', 'models', 'ureshape_resnet_model_edgetpu_accelerator', 't_time.npy'))

print('-------------FOR EdgeTPU Accelerator Board---------')
print('-------------For Inference-------------')
print(f'Total Number of Images : {len(p_time)}')
print(f'Max Inference Time is : {round(np.max(p_time[1:]), 6)} secs')
print(f'Min Inference Time is : {round(np.min(p_time[1:]), 6)} secs')
print(f'Average Inference Time is : {round(np.average(p_time[1:]), 6)} secs')
print(f'Mean Inference Time is : {round(np.mean(p_time[1:]), 6)} secs')

plt.plot(p_time[1:])
plt.ylabel('Time in secs')
plt.xlabel('Iterations')
plt.show()
# Out:
# -------------FOR EdgeTPU Accelerator Board---------
# -------------For Inference-------------
# Total Number of Images : 100
# Max Inference Time is : 0.545284 secs
# Min Inference Time is : 0.515713 secs
# Average Inference Time is : 0.537362 secs
# Mean Inference Time is : 0.537362 secs

# %%
print('------------For Preprocessing----------')
print(f'Total Number of Images : {len(pp_time)}')
print(f'Max Preprocessing Time is : {round(np.max(pp_time[1:]), 6)} secs')
print(f'Min Preprocessing Time is : {round(np.min(pp_time[1:]), 6)} secs')
print(f'Average v Time is : {round(np.average(pp_time[1:]), 6)} secs')
print(f'Mean Preprocessing Time is : {round(np.mean(pp_time[1:]), 6)} secs')

plt.plot(pp_time)
plt.ylabel('Time in secs')
plt.xlabel('Iterations')
plt.show()
# Out:
# ------------For Preprocessing----------
# Total Number of Images : 100
# Max Preprocessing Time is : 0.418761 secs
# Min Preprocessing Time is : 0.365757 secs
# Average v Time is : 0.376747 secs
# Mean Preprocessing Time is : 0.376747 secs

# %%
print('----------Total Time-----------')
print(f'Total Number of Images : {len(t_time)}')
print(f'Max Time is : {round(np.max(t_time[1:]), 6)} msecs')
print(f'Min Time is : {round(np.min(t_time[1:]), 6)} secs')
print(f'Average Time is : {round(np.average(t_time[1:]), 6)} secs')
print(f'Average Time is : {round(np.mean(t_time[1:]), 6)} secs')

plt.plot(t_time)
plt.ylabel('Time in secs')
plt.xlabel('Iterations')
plt.show()
# Out:
# ----------Total Time-----------
# Total Number of Images : 100
# Max Time is : 0.960001 msecs
# Min Time is : 0.889958 secs
# Average Time is : 0.914129 secs
# Average Time is : 0.914129 secs
