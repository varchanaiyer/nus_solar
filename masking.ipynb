# %%
import cv2
import numpy as np
import os
import glob
from matplotlib import pyplot as plt

# %%
paths=glob.glob(os.path.join('..', 'Solar_Panel_Soiling_Image_dataset', '*', '*.jpg'))

# %%
for path in paths[0:10]:
    img=cv2.imread(path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    gray = cv2.bilateralFilter(gray, 11, 17, 17)
    edged = cv2.Canny(gray, 30, 200)
    cnts = cv2.findContours(edged.copy(), cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
# Out:
# ([array([[[191, 189]],
#
#        [[190, 190]],
#
#        [[190, 191]],
#
#        [[191, 190]]], dtype=int32), array([[[ 92, 177]],
#
#        [[ 90, 179]],
#
#        [[ 91, 180]],
#
#        [[ 92, 180]],
#
#        [[ 93, 179]],
#
#        [[ 95, 179]],
#
#        [[ 96, 180]],
#
#        [[ 95, 181]],
#
#        [[ 96, 181]],
#
#        [[ 96, 177]]], dtype=int32), array([[[ 90, 179]],
#
#        [[ 91, 178]],
#
#        [[ 92, 178]],
#
#        [[ 93, 179]],
#
#        [[ 92, 180]],
#
#        [[ 91, 180]]], dtype=int32), array([[[ 94, 178]],
#
#        [[ 95, 177]],
#
#        [[ 96, 178]],
#
#        [[ 95, 179]]], dtype=int32), array([[[ 92, 178]],
#
#        [[ 93, 177]],
#
#        [[ 94, 178]],
#
#        [[ 93, 179]]], dtype=int32), array([[[ 62, 170]],
#
#        [[ 62, 171]],
#
#        [[ 63, 172]],
#
#        [[ 65, 172]],
#
#        [[ 64, 171]],
#
#        [[ 64, 170]]], dtype=int32), array([[[ 62, 171]],
#
#        [[ 63, 170]],
#
#        [[ 64, 171]],
#
#        [[ 63, 172]]], dtype=int32), array([[[147, 165]],
#
#        [[148, 165]]], dtype=int32), array([[[126, 162]],
#
#        [[128, 162]]], dtype=int32), array([[[120, 161]],
#
#        [[123, 161]]], dtype=int32), array([[[114, 160]],
#
#        [[117, 160]]], dtype=int32), array([[[122, 159]],
#
#        [[127, 159]],
#
#        [[128, 160]],
#
#        [[132, 160]],
#
#        [[133, 161]],
#
#        [[140, 161]],
#
#        [[141, 162]],
#
#        [[144, 162]],
#
#        [[145, 163]],
#
#        [[150, 163]],
#
#        [[151, 164]],
#
#        [[156, 164]],
#
#        [[157, 165]],
#
#        [[162, 165]],
#
#        [[163, 166]],
#
#        [[169, 166]],
#
#        [[170, 167]],
#
#        [[176, 167]],
#
#        [[177, 168]],
#
#        [[184, 168]],
#
#        [[185, 169]],
#
#        [[191, 169]],
#
#        [[185, 169]],
#
#        [[184, 168]],
#
#        [[177, 168]],
#
#        [[176, 167]],
#
#        [[170, 167]],
#
#        [[169, 166]],
#
#        [[163, 166]],
#
#        [[162, 165]],
#
#        [[157, 165]],
#
#        [[156, 164]],
#
#        [[151, 164]],
#
#        [[150, 163]],
#
#        [[145, 163]],
#
#        [[144, 162]],
#
#        [[141, 162]],
#
#        [[140, 161]],
#
#        [[133, 161]],
#
#        [[132, 160]],
#
#        [[128, 160]],
#
#        [[127, 159]]], dtype=int32), array([[[108, 159]],
#
#        [[111, 159]]], dtype=int32), array([[[116, 158]],
#
#        [[120, 158]]], dtype=int32), array([[[105, 156]],
#
#        [[107, 156]],
#
#        [[108, 157]],
#
#        [[114, 157]],
#
#        [[108, 157]],
#
#        [[107, 156]]], dtype=int32), array([[[ 99, 155]],
#
#        [[102, 155]]], dtype=int32), array([[[ 85, 155]],
#
#        [[ 89, 155]],
#
#        [[ 90, 156]],
#
#        [[ 95, 156]],
#
#        [[ 96, 157]],
#
#        [[100, 157]],
#
#        [[101, 158]],
#
#        [[105, 158]],
#
#        [[101, 158]],
#
#        [[100, 157]],
#
#        [[ 96, 157]],
#
#        [[ 95, 156]],
#
#        [[ 90, 156]],
#
#        [[ 89, 155]]], dtype=int32), array([[[ 93, 154]],
#
#        [[ 96, 154]]], dtype=int32), array([[[ 79, 154]],
#
#        [[ 81, 154]]], dtype=int32), array([[[ 74, 153]],
#
#        [[ 76, 153]]], dtype=int32), array([[[ 13, 153]],
#
#        [[ 10, 156]],
#
#        [[  9, 156]],
#
#        [[  9, 157]],
#
#        [[  5, 161]],
#
#        [[  3, 161]],
#
#        [[  2, 162]],
#
#        [[  2, 163]],
#
#        [[  0, 165]],
#
#        [[  1, 165]],
#
#        [[  2, 164]],
#
#        [[  4, 166]],
#
#        [[  3, 167]],
#
#        [[  3, 169]],
#
#        [[  4, 170]],
#
#        [[  4, 172]],
#
#        [[  5, 172]],
#
#        [[  6, 173]],
#
#        [[  4, 175]],
#
#        [[  2, 173]],
#
#        [[  1, 174]],
#
#        [[  0, 173]],
#
#        [[  1, 174]],
#
#        [[  2, 173]],
#
#        [[  4, 175]],
#
#        [[  1, 178]],
#
#        [[  1, 180]],
#
#        [[  2, 180]],
#
#        [[  3, 181]],
#
#        [[  4, 181]],
#
#        [[  6, 183]],
#
#        [[  7, 183]],
#
#        [[  8, 184]],
#
#        [[ 10, 184]],
#
#        [[ 11, 185]],
#
#        [[ 12, 185]],
#
#        [[ 13, 186]],
#
#        [[ 14, 186]],
#
#        [[ 13, 186]],
#
#        [[ 12, 185]],
#
#        [[ 11, 185]],
#
#        [[ 10, 184]],
#
#        [[  9, 184]],
#
#        [[  8, 183]],
#
#        [[  7, 183]],
#
#        [[  5, 181]],
#
#        [[  4, 181]],
#
#        [[  3, 180]],
#
#        [[  2, 180]],
#
#        [[  1, 179]],
#
#        [[  1, 178]],
#
#        [[  2, 177]],
#
#        [[  3, 177]],
#
#        [[  8, 172]],
#
#        [[  9, 172]],
#
#        [[ 10, 171]],
#
#        [[ 11, 171]],
#
#        [[ 12, 172]],
#
#        [[ 12, 175]],
#
#        [[ 13, 176]],
#
#        [[ 13, 178]],
#
#        [[ 14, 179]],
#
#        [[ 14, 181]],
#
#        [[ 15, 182]],
#
#        [[ 15, 184]],
#
#        [[ 16, 185]],
#
#        [[ 16, 189]],
#
#        [[ 15, 190]],
#
#        [[ 12, 190]],
#
#        [[ 11, 191]],
#
#        [[ 12, 191]],
#
#        [[ 13, 190]],
#
#        [[ 14, 190]],
#
#        [[ 15, 191]],
#
#        [[ 15, 190]],
#
#        [[ 16, 189]],
#
#        [[ 16, 185]],
#
#        [[ 15, 184]],
#
#        [[ 15, 182]],
#
#        [[ 14, 181]],
#
#        [[ 14, 179]],
#
#        [[ 13, 178]],
#
#        [[ 13, 176]],
#
#        [[ 12, 175]],
#
#        [[ 12, 172]],
#
#        [[ 11, 171]],
#
#        [[ 11, 170]],
#
#        [[ 10, 171]],
#
#        [[  9, 171]],
#
#        [[  8, 172]],
#
#        [[  7, 172]],
#
#        [[  6, 173]],
#
#        [[  4, 171]],
#
#        [[  5, 170]],
#
#        [[  4, 170]],
#
#        [[  3, 169]],
#
#        [[  3, 168]],
#
#        [[  4, 167]],
#
#        [[  4, 166]],
#
#        [[  6, 164]],
#
#        [[  7, 165]],
#
#        [[  8, 165]],
#
#        [[  9, 164]],
#
#        [[  5, 164]],
#
#        [[  5, 165]],
#
#        [[  4, 166]],
#
#        [[  2, 164]],
#
#        [[  2, 163]],
#
#        [[  4, 161]],
#
#        [[  6, 161]],
#
#        [[  8, 159]],
#
#        [[  8, 158]],
#
#        [[ 10, 156]],
#
#        [[ 11, 156]],
#
#        [[ 13, 154]]], dtype=int32), array([[[ 31, 152]],
#
#        [[ 29, 154]],
#
#        [[ 28, 153]],
#
#        [[ 29, 154]],
#
#        [[ 25, 158]],
#
#        [[ 24, 158]],
#
#        [[ 21, 161]],
#
#        [[ 20, 161]],
#
#        [[ 20, 162]],
#
#        [[ 19, 163]],
#
#        [[ 14, 163]],
#
#        [[ 13, 164]],
#
#        [[ 12, 164]],
#
#        [[ 10, 166]],
#
#        [[ 10, 168]],
#
#        [[ 10, 167]],
#
#        [[ 14, 163]],
#
#        [[ 18, 163]],
#
#        [[ 19, 164]],
#
#        [[ 20, 164]],
#
#        [[ 23, 167]],
#
#        [[ 23, 169]],
#
#        [[ 24, 170]],
#
#        [[ 24, 172]],
#
#        [[ 25, 173]],
#
#        [[ 25, 176]],
#
#        [[ 26, 177]],
#
#        [[ 26, 180]],
#
#        [[ 27, 181]],
#
#        [[ 27, 182]],
#
#        [[ 28, 183]],
#
#        [[ 28, 187]],
#
#        [[ 29, 188]],
#
#        [[ 29, 190]],
#
#        [[ 30, 191]],
#
#        [[ 29, 190]],
#
#        [[ 29, 188]],
#
#        [[ 28, 187]],
#
#        [[ 28, 183]],
#
#        [[ 27, 182]],
#
#        [[ 27, 181]],
#
#        [[ 26, 180]],
#
#        [[ 26, 177]],
#
#        [[ 25, 176]],
#
#        [[ 25, 173]],
#
#        [[ 24, 172]],
#
#        [[ 24, 170]],
#
#        [[ 23, 169]],
#
#        [[ 23, 166]],
#
#        [[ 24, 165]],
#
#        [[ 25, 165]],
#
#        [[ 25, 163]],
#
#        [[ 26, 162]],
#
#        [[ 25, 163]],
#
#        [[ 23, 163]],
#
#        [[ 24, 163]],
#
#        [[ 25, 164]],
#
#        [[ 23, 166]],
#
#        [[ 21, 164]],
#
#        [[ 20, 164]],
#
#        [[ 19, 163]],
#
#        [[ 21, 161]],
#
#        [[ 22, 161]],
#
#        [[ 25, 158]],
#
#        [[ 26, 158]],
#
#        [[ 29, 155]],
#
#        [[ 38, 155]],
#
#        [[ 39, 154]],
#
#        [[ 43, 158]],
#
#        [[ 42, 159]],
#
#        [[ 41, 159]],
#
#        [[ 39, 161]],
#
#        [[ 38, 161]],
#
#        [[ 38, 164]],
#
#        [[ 44, 164]],
#
#        [[ 46, 162]],
#
#        [[ 47, 162]],
#
#        [[ 47, 160]],
#
#        [[ 49, 158]],
#
#        [[ 50, 158]],
#
#        [[ 51, 159]],
#
#        [[ 52, 159]],
#
#        [[ 53, 160]],
#
#        [[ 55, 160]],
#
#        [[ 56, 161]],
#
#        [[ 58, 161]],
#
#        [[ 59, 162]],
#
#        [[ 61, 162]],
#
#        [[ 62, 163]],
#
#        [[ 63, 163]],
#
#        [[ 64, 164]],
#
#        [[ 65, 164]],
#
#        [[ 64, 164]],
#
#        [[ 63, 163]],
#
#        [[ 62, 163]],
#
#        [[ 61, 162]],
#
#        [[ 59, 162]],
#
#        [[ 58, 161]],
#
#        [[ 56, 161]],
#
#        [[ 55, 160]],
#
#        [[ 53, 160]],
#
#        [[ 51, 158]],
#
#        [[ 49, 158]],
#
#        [[ 48, 159]],
#
#        [[ 47, 158]],
#
#        [[ 47, 157]],
#
#        [[ 46, 157]],
#
#        [[ 45, 156]],
#
#        [[ 45, 157]],
#
#        [[ 44, 158]],
#
#        [[ 43, 158]],
#
#        [[ 42, 157]],
#
#        [[ 42, 156]],
#
#        [[ 41, 155]],
#
#        [[ 40, 155]],
#
#        [[ 39, 154]],
#
#        [[ 38, 155]],
#
#        [[ 31, 155]],
#
#        [[ 30, 154]],
#
#        [[ 31, 153]],
#
#        [[ 32, 153]],
#
#        [[ 32, 152]]], dtype=int32), array([[[ 42, 159]],
#
#        [[ 43, 159]],
#
#        [[ 44, 160]],
#
#        [[ 44, 161]],
#
#        [[ 45, 162]],
#
#        [[ 43, 164]],
#
#        [[ 39, 164]],
#
#        [[ 38, 163]],
#
#        [[ 38, 162]],
#
#        [[ 39, 161]],
#
#        [[ 40, 161]]], dtype=int32), array([[[ 43, 159]],
#
#        [[ 44, 158]],
#
#        [[ 45, 158]],
#
#        [[ 47, 160]],
#
#        [[ 47, 161]],
#
#        [[ 46, 162]],
#
#        [[ 45, 162]],
#
#        [[ 44, 161]],
#
#        [[ 44, 160]]], dtype=int32), array([[[ 45, 158]],
#
#        [[ 46, 157]],
#
#        [[ 47, 158]],
#
#        [[ 46, 159]]], dtype=int32), array([[[ 74, 151]],
#
#        [[ 79, 151]],
#
#        [[ 80, 152]],
#
#        [[ 82, 152]],
#
#        [[ 83, 153]],
#
#        [[ 90, 153]],
#
#        [[ 83, 153]],
#
#        [[ 82, 152]],
#
#        [[ 80, 152]],
#
#        [[ 79, 151]]], dtype=int32), array([[[ 63, 151]],
#
#        [[ 67, 151]],
#
#        [[ 68, 152]],
#
#        [[ 71, 152]],
#
#        [[ 68, 152]],
#
#        [[ 67, 151]]], dtype=int32), array([[[ 70, 150]],
#
#        [[ 72, 150]]], dtype=int32), array([[[ 46, 150]],
#
#        [[ 50, 150]],
#
#        [[ 51, 151]],
#
#        [[ 55, 151]],
#
#        [[ 56, 152]],
#
#        [[ 61, 152]],
#
#        [[ 62, 153]],
#
#        [[ 66, 153]],
#
#        [[ 62, 153]],
#
#        [[ 61, 152]],
#
#        [[ 56, 152]],
#
#        [[ 55, 151]],
#
#        [[ 51, 151]],
#
#        [[ 50, 150]]], dtype=int32), array([[[ 56, 149]],
#
#        [[ 57, 150]],
#
#        [[ 60, 150]],
#
#        [[ 57, 150]]], dtype=int32), array([[[ 52, 149]],
#
#        [[ 54, 149]]], dtype=int32), array([[[ 42, 149]],
#
#        [[ 44, 149]]], dtype=int32), array([[[ 50, 148]]], dtype=int32), array([[[ 46, 148]],
#
#        [[ 47, 148]]], dtype=int32), array([[[ 42, 147]],
#
#        [[ 44, 147]]], dtype=int32), array([[[188, 141]],
#
#        [[188, 144]]], dtype=int32), array([[[191, 138]],
#
#        [[191, 142]],
#
#        [[190, 143]],
#
#        [[191, 144]],
#
#        [[189, 146]],
#
#        [[189, 150]],
#
#        [[187, 152]],
#
#        [[186, 151]],
#
#        [[186, 150]],
#
#        [[187, 149]],
#
#        [[187, 146]],
#
#        [[187, 149]],
#
#        [[186, 150]],
#
#        [[186, 151]],
#
#        [[185, 152]],
#
#        [[184, 151]],
#
#        [[184, 150]],
#
#        [[184, 153]],
#
#        [[185, 152]],
#
#        [[186, 153]],
#
#        [[186, 154]],
#
#        [[185, 155]],
#
#        [[185, 159]],
#
#        [[184, 160]],
#
#        [[183, 159]],
#
#        [[183, 155]],
#
#        [[183, 159]],
#
#        [[182, 160]],
#
#        [[182, 163]],
#
#        [[182, 160]],
#
#        [[183, 159]],
#
#        [[184, 160]],
#
#        [[184, 163]],
#
#        [[184, 160]],
#
#        [[185, 159]],
#
#        [[185, 155]],
#
#        [[186, 154]],
#
#        [[186, 153]],
#
#        [[187, 152]],
#
#        [[188, 153]],
#
#        [[188, 155]],
#
#        [[187, 156]],
#
#        [[187, 160]],
#
#        [[186, 161]],
#
#        [[186, 163]],
#
#        [[186, 161]],
#
#        [[187, 160]],
#
#        [[188, 161]],
#
#        [[188, 164]],
#
#        [[188, 161]],
#
#        [[189, 160]],
#
#        [[189, 157]],
#
#        [[189, 160]],
#
#        [[188, 161]],
#
#        [[187, 160]],
#
#        [[187, 156]],
#
#        [[188, 155]],
#
#        [[188, 151]],
#
#        [[189, 150]],
#
#        [[190, 151]],
#
#        [[190, 155]],
#
#        [[190, 151]],
#
#        [[191, 150]],
#
#        [[191, 147]],
#
#        [[191, 150]],
#
#        [[190, 151]],
#
#        [[189, 150]],
#
#        [[189, 146]],
#
#        [[191, 144]],
#
#        [[190, 143]],
#
#        [[191, 142]]], dtype=int32), array([[[187, 119]],
#
#        [[187, 121]],
#
#        [[186, 122]],
#
#        [[186, 126]],
#
#        [[187, 127]],
#
#        [[187, 130]],
#
#        [[186, 131]],
#
#        [[185, 130]],
#
#        [[185, 128]],
#
#        [[180, 128]],
#
#        [[179, 129]],
#
#        [[179, 131]],
#
#        [[179, 129]],
#
#        [[180, 128]],
#
#        [[184, 128]],
#
#        [[185, 129]],
#
#        [[185, 130]],
#
#        [[184, 131]],
#
#        [[184, 134]],
#
#        [[185, 133]],
#
#        [[186, 134]],
#
#        [[186, 131]],
#
#        [[187, 130]],
#
#        [[188, 131]],
#
#        [[188, 135]],
#
#        [[187, 136]],
#
#        [[187, 138]],
#
#        [[186, 139]],
#
#        [[185, 138]],
#
#        [[185, 136]],
#
#        [[185, 139]],
#
#        [[187, 139]],
#
#        [[187, 136]],
#
#        [[188, 135]],
#
#        [[189, 136]],
#
#        [[189, 139]],
#
#        [[189, 136]],
#
#        [[190, 135]],
#
#        [[190, 131]],
#
#        [[191, 130]],
#
#        [[191, 127]],
#
#        [[190, 126]],
#
#        [[190, 124]],
#
#        [[191, 123]],
#
#        [[191, 121]],
#
#        [[191, 123]],
#
#        [[190, 124]],
#
#        [[190, 125]],
#
#        [[189, 126]],
#
#        [[189, 130]],
#
#        [[188, 131]],
#
#        [[187, 130]],
#
#        [[187, 126]],
#
#        [[186, 125]],
#
#        [[186, 122]],
#
#        [[187, 121]]], dtype=int32), array([[[188, 131]],
#
#        [[189, 130]],
#
#        [[190, 131]],
#
#        [[190, 135]],
#
#        [[189, 136]],
#
#        [[188, 135]]], dtype=int32), array([[[184, 131]],
#
#        [[185, 130]],
#
#        [[186, 131]],
#
#        [[186, 132]],
#
#        [[185, 133]],
#
#        [[184, 132]]], dtype=int32), array([[[189, 127]],
#
#        [[190, 126]],
#
#        [[191, 127]],
#
#        [[191, 130]],
#
#        [[190, 131]],
#
#        [[189, 130]]], dtype=int32), array([[[ 36,  92]],
#
#        [[ 35,  93]],
#
#        [[ 35,  94]],
#
#        [[ 34,  95]],
#
#        [[ 34,  96]],
#
#        [[ 33,  97]],
#
#        [[ 33,  98]],
#
#        [[ 32,  99]],
#
#        [[ 32, 100]],
#
#        [[ 31, 101]],
#
#        [[ 31, 102]],
#
#        [[ 30, 103]],
#
#        [[ 30, 104]],
#
#        [[ 29, 105]],
#
#        [[ 29, 107]],
#
#        [[ 27, 109]],
#
#        [[ 27, 110]],
#
#        [[ 26, 111]],
#
#        [[ 26, 112]],
#
#        [[ 25, 113]],
#
#        [[ 25, 115]],
#
#        [[ 23, 117]],
#
#        [[ 23, 119]],
#
#        [[ 21, 121]],
#
#        [[ 21, 123]],
#
#        [[ 20, 124]],
#
#        [[ 20, 125]],
#
#        [[ 19, 126]],
#
#        [[ 19, 127]],
#
#        [[ 18, 128]],
#
#        [[ 18, 129]],
#
#        [[ 17, 130]],
#
#        [[ 17, 131]],
#
#        [[ 16, 132]],
#
#        [[ 16, 133]],
#
#        [[ 15, 134]],
#
#        [[ 15, 136]],
#
#        [[ 14, 137]],
#
#        [[ 14, 139]],
#
#        [[ 13, 140]],
#
#        [[ 13, 144]],
#
#        [[ 14, 145]],
#
#        [[ 14, 146]],
#
#        [[ 16, 148]],
#
#        [[ 16, 149]],
#
#        [[ 17, 150]],
#
#        [[ 19, 150]],
#
#        [[ 19, 148]],
#
#        [[ 18, 147]],
#
#        [[ 18, 146]],
#
#        [[ 19, 145]],
#
#        [[ 22, 145]],
#
#        [[ 23, 146]],
#
#        [[ 22, 147]],
#
#        [[ 21, 147]],
#
#        [[ 21, 148]],
#
#        [[ 22, 149]],
#
#        [[ 23, 149]],
#
#        [[ 24, 148]],
#
#        [[ 23, 147]],
#
#        [[ 23, 145]],
#
#        [[ 20, 145]],
#
#        [[ 19, 144]],
#
#        [[ 19, 145]],
#
#        [[ 18, 146]],
#
#        [[ 18, 147]],
#
#        [[ 19, 148]],
#
#        [[ 19, 149]],
#
#        [[ 18, 150]],
#
#        [[ 16, 148]],
#
#        [[ 16, 147]],
#
#        [[ 14, 145]],
#
#        [[ 14, 144]],
#
#        [[ 13, 143]],
#
#        [[ 13, 140]],
#
#        [[ 14, 139]],
#
#        [[ 15, 140]],
#
#        [[ 19, 140]],
#
#        [[ 20, 141]],
#
#        [[ 23, 141]],
#
#        [[ 24, 142]],
#
#        [[ 29, 142]],
#
#        [[ 30, 143]],
#
#        [[ 35, 143]],
#
#        [[ 36, 144]],
#
#        [[ 41, 144]],
#
#        [[ 42, 145]],
#
#        [[ 45, 145]],
#
#        [[ 46, 146]],
#
#        [[ 51, 146]],
#
#        [[ 52, 147]],
#
#        [[ 57, 147]],
#
#        [[ 58, 148]],
#
#        [[ 61, 148]],
#
#        [[ 62, 149]],
#
#        [[ 67, 149]],
#
#        [[ 62, 149]],
#
#        [[ 61, 148]],
#
#        [[ 58, 148]],
#
#        [[ 57, 147]],
#
#        [[ 52, 147]],
#
#        [[ 51, 146]],
#
#        [[ 46, 146]],
#
#        [[ 45, 145]],
#
#        [[ 42, 145]],
#
#        [[ 41, 144]],
#
#        [[ 36, 144]],
#
#        [[ 35, 143]],
#
#        [[ 30, 143]],
#
#        [[ 29, 142]],
#
#        [[ 24, 142]],
#
#        [[ 23, 141]],
#
#        [[ 20, 141]],
#
#        [[ 19, 140]],
#
#        [[ 16, 140]],
#
#        [[ 14, 138]],
#
#        [[ 14, 137]],
#
#        [[ 15, 136]],
#
#        [[ 15, 135]],
#
#        [[ 16, 134]],
#
#        [[ 16, 132]],
#
#        [[ 18, 130]],
#
#        [[ 18, 128]],
#
#        [[ 19, 127]],
#
#        [[ 19, 126]],
#
#        [[ 20, 125]],
#
#        [[ 20, 124]],
#
#        [[ 21, 123]],
#
#        [[ 21, 122]],
#
#        [[ 22, 121]],
#
#        [[ 22, 120]],
#
#        [[ 23, 119]],
#
#        [[ 23, 118]],
#
#        [[ 24, 117]],
#
#        [[ 24, 116]],
#
#        [[ 25, 115]],
#
#        [[ 25, 114]],
#
#        [[ 26, 113]],
#
#        [[ 26, 112]],
#
#        [[ 27, 111]],
#
#        [[ 27, 110]],
#
#        [[ 28, 109]],
#
#        [[ 28, 108]],
#
#        [[ 29, 107]],
#
#        [[ 29, 105]],
#
#        [[ 31, 103]],
#
#        [[ 31, 102]],
#
#        [[ 32, 101]],
#
#        [[ 32,  99]],
#
#        [[ 33,  98]],
#
#        [[ 33,  97]],
#
#        [[ 34,  96]],
#
#        [[ 34,  95]],
#
#        [[ 35,  94]],
#
#        [[ 35,  93]]], dtype=int32), array([[[ 21, 148]],
#
#        [[ 22, 147]],
#
#        [[ 23, 147]],
#
#        [[ 24, 148]],
#
#        [[ 23, 149]],
#
#        [[ 22, 149]]], dtype=int32), array([[[38, 84]]], dtype=int32), array([[[41, 73]],
#
#        [[41, 75]]], dtype=int32), array([[[45, 54]],
#
#        [[44, 55]],
#
#        [[44, 57]],
#
#        [[43, 58]],
#
#        [[43, 61]],
#
#        [[42, 62]],
#
#        [[42, 65]],
#
#        [[41, 66]],
#
#        [[41, 67]],
#
#        [[40, 68]],
#
#        [[39, 67]],
#
#        [[40, 68]],
#
#        [[40, 71]],
#
#        [[39, 72]],
#
#        [[39, 75]],
#
#        [[39, 72]],
#
#        [[40, 71]],
#
#        [[40, 69]],
#
#        [[41, 68]],
#
#        [[42, 69]],
#
#        [[42, 71]],
#
#        [[42, 69]],
#
#        [[43, 68]],
#
#        [[43, 66]],
#
#        [[44, 65]],
#
#        [[44, 63]],
#
#        [[45, 62]],
#
#        [[45, 59]],
#
#        [[46, 58]],
#
#        [[46, 56]],
#
#        [[46, 58]],
#
#        [[45, 59]],
#
#        [[44, 58]],
#
#        [[44, 55]],
#
#        [[45, 54]],
#
#        [[46, 54]]], dtype=int32), array([[[41, 66]],
#
#        [[42, 65]],
#
#        [[43, 66]],
#
#        [[43, 68]],
#
#        [[42, 69]],
#
#        [[41, 68]]], dtype=int32), array([[[42, 63]],
#
#        [[43, 62]],
#
#        [[44, 63]],
#
#        [[44, 65]],
#
#        [[43, 66]],
#
#        [[42, 65]]], dtype=int32), array([[[43, 59]],
#
#        [[44, 58]],
#
#        [[45, 59]],
#
#        [[45, 62]],
#
#        [[44, 63]],
#
#        [[43, 62]]], dtype=int32), array([[[191,  39]],
#
#        [[191,  40]],
#
#        [[190,  41]],
#
#        [[190,  42]],
#
#        [[191,  43]],
#
#        [[191,  45]],
#
#        [[190,  46]],
#
#        [[190,  48]],
#
#        [[189,  49]],
#
#        [[189,  51]],
#
#        [[188,  52]],
#
#        [[188,  55]],
#
#        [[187,  56]],
#
#        [[187,  58]],
#
#        [[186,  59]],
#
#        [[186,  61]],
#
#        [[185,  62]],
#
#        [[185,  64]],
#
#        [[184,  65]],
#
#        [[184,  68]],
#
#        [[183,  69]],
#
#        [[183,  71]],
#
#        [[182,  72]],
#
#        [[182,  75]],
#
#        [[181,  76]],
#
#        [[181,  78]],
#
#        [[180,  79]],
#
#        [[180,  81]],
#
#        [[179,  82]],
#
#        [[179,  85]],
#
#        [[178,  86]],
#
#        [[178,  88]],
#
#        [[177,  89]],
#
#        [[177,  92]],
#
#        [[176,  93]],
#
#        [[176,  96]],
#
#        [[175,  97]],
#
#        [[175,  99]],
#
#        [[174, 100]],
#
#        [[174, 103]],
#
#        [[173, 104]],
#
#        [[173, 107]],
#
#        [[172, 108]],
#
#        [[172, 110]],
#
#        [[171, 111]],
#
#        [[171, 114]],
#
#        [[170, 115]],
#
#        [[170, 118]],
#
#        [[169, 119]],
#
#        [[169, 122]],
#
#        [[168, 123]],
#
#        [[168, 126]],
#
#        [[167, 127]],
#
#        [[167, 130]],
#
#        [[166, 131]],
#
#        [[166, 133]],
#
#        [[165, 134]],
#
#        [[165, 138]],
#
#        [[164, 139]],
#
#        [[164, 141]],
#
#        [[163, 142]],
#
#        [[163, 145]],
#
#        [[162, 146]],
#
#        [[162, 150]],
#
#        [[161, 151]],
#
#        [[161, 154]],
#
#        [[160, 155]],
#
#        [[160, 158]],
#
#        [[159, 159]],
#
#        [[159, 162]],
#
#        [[162, 162]],
#
#        [[163, 163]],
#
#        [[169, 163]],
#
#        [[170, 164]],
#
#        [[176, 164]],
#
#        [[177, 165]],
#
#        [[185, 165]],
#
#        [[186, 166]],
#
#        [[191, 166]],
#
#        [[186, 166]],
#
#        [[185, 165]],
#
#        [[177, 165]],
#
#        [[176, 164]],
#
#        [[170, 164]],
#
#        [[169, 163]],
#
#        [[163, 163]],
#
#        [[162, 162]],
#
#        [[160, 162]],
#
#        [[159, 161]],
#
#        [[159, 159]],
#
#        [[160, 158]],
#
#        [[160, 155]],
#
#        [[161, 154]],
#
#        [[161, 151]],
#
#        [[162, 150]],
#
#        [[162, 146]],
#
#        [[163, 145]],
#
#        [[163, 142]],
#
#        [[164, 141]],
#
#        [[164, 139]],
#
#        [[165, 138]],
#
#        [[165, 134]],
#
#        [[166, 133]],
#
#        [[166, 131]],
#
#        [[167, 130]],
#
#        [[167, 127]],
#
#        [[168, 126]],
#
#        [[168, 123]],
#
#        [[169, 122]],
#
#        [[169, 119]],
#
#        [[170, 118]],
#
#        [[170, 115]],
#
#        [[171, 114]],
#
#        [[171, 111]],
#
#        [[172, 110]],
#
#        [[172, 108]],
#
#        [[173, 107]],
#
#        [[173, 104]],
#
#        [[174, 103]],
#
#        [[174, 100]],
#
#        [[175,  99]],
#
#        [[175,  97]],
#
#        [[176,  96]],
#
#        [[176,  93]],
#
#        [[177,  92]],
#
#        [[177,  89]],
#
#        [[178,  88]],
#
#        [[178,  86]],
#
#        [[179,  85]],
#
#        [[179,  82]],
#
#        [[180,  81]],
#
#        [[180,  79]],
#
#        [[181,  78]],
#
#        [[181,  76]],
#
#        [[182,  75]],
#
#        [[182,  72]],
#
#        [[183,  71]],
#
#        [[183,  69]],
#
#        [[184,  68]],
#
#        [[184,  65]],
#
#        [[185,  64]],
#
#        [[185,  62]],
#
#        [[186,  61]],
#
#        [[186,  59]],
#
#        [[187,  58]],
#
#        [[187,  56]],
#
#        [[188,  55]],
#
#        [[188,  52]],
#
#        [[189,  51]],
#
#        [[189,  49]],
#
#        [[190,  48]],
#
#        [[190,  46]],
#
#        [[191,  45]],
#
#        [[191,  43]],
#
#        [[190,  42]],
#
#        [[190,  41]],
#
#        [[191,  40]]], dtype=int32), array([[[174,  26]],
#
#        [[174,  28]],
#
#        [[172,  30]],
#
#        [[170,  30]],
#
#        [[172,  30]],
#
#        [[173,  29]],
#
#        [[174,  29]],
#
#        [[175,  30]],
#
#        [[182,  30]],
#
#        [[183,  31]],
#
#        [[187,  31]],
#
#        [[188,  32]],
#
#        [[191,  32]],
#
#        [[188,  32]],
#
#        [[187,  31]],
#
#        [[183,  31]],
#
#        [[182,  30]],
#
#        [[176,  30]],
#
#        [[174,  28]]], dtype=int32), array([[[176,  23]],
#
#        [[176,  26]],
#
#        [[179,  26]],
#
#        [[180,  27]],
#
#        [[186,  27]],
#
#        [[187,  28]],
#
#        [[191,  28]],
#
#        [[187,  28]],
#
#        [[186,  27]],
#
#        [[180,  27]],
#
#        [[179,  26]],
#
#        [[177,  26]],
#
#        [[176,  25]]], dtype=int32), array([[[122,  23]],
#
#        [[128,  23]],
#
#        [[129,  24]],
#
#        [[133,  24]],
#
#        [[134,  25]],
#
#        [[145,  25]],
#
#        [[146,  26]],
#
#        [[150,  26]],
#
#        [[151,  27]],
#
#        [[155,  27]],
#
#        [[156,  28]],
#
#        [[162,  28]],
#
#        [[163,  29]],
#
#        [[168,  29]],
#
#        [[163,  29]],
#
#        [[162,  28]],
#
#        [[156,  28]],
#
#        [[155,  27]],
#
#        [[151,  27]],
#
#        [[150,  26]],
#
#        [[146,  26]],
#
#        [[145,  25]],
#
#        [[134,  25]],
#
#        [[133,  24]],
#
#        [[129,  24]],
#
#        [[128,  23]]], dtype=int32), array([[[76, 21]],
#
#        [[75, 22]],
#
#        [[75, 23]],
#
#        [[73, 25]],
#
#        [[73, 26]],
#
#        [[72, 27]],
#
#        [[72, 28]],
#
#        [[70, 30]],
#
#        [[70, 31]],
#
#        [[69, 32]],
#
#        [[69, 33]],
#
#        [[68, 34]],
#
#        [[68, 35]],
#
#        [[66, 37]],
#
#        [[66, 38]],
#
#        [[64, 40]],
#
#        [[64, 41]],
#
#        [[63, 42]],
#
#        [[63, 43]],
#
#        [[62, 44]],
#
#        [[62, 45]],
#
#        [[60, 47]],
#
#        [[60, 48]],
#
#        [[59, 49]],
#
#        [[59, 50]],
#
#        [[58, 51]],
#
#        [[58, 52]],
#
#        [[56, 54]],
#
#        [[56, 55]],
#
#        [[55, 56]],
#
#        [[55, 57]],
#
#        [[53, 59]],
#
#        [[53, 61]],
#
#        [[52, 62]],
#
#        [[52, 63]],
#
#        [[50, 65]],
#
#        [[50, 66]],
#
#        [[49, 67]],
#
#        [[49, 68]],
#
#        [[48, 69]],
#
#        [[48, 70]],
#
#        [[46, 72]],
#
#        [[46, 73]],
#
#        [[45, 74]],
#
#        [[45, 75]],
#
#        [[44, 76]],
#
#        [[44, 77]],
#
#        [[43, 78]],
#
#        [[43, 79]],
#
#        [[42, 80]],
#
#        [[42, 81]],
#
#        [[40, 83]],
#
#        [[39, 82]],
#
#        [[39, 80]],
#
#        [[40, 79]],
#
#        [[40, 77]],
#
#        [[40, 79]],
#
#        [[39, 80]],
#
#        [[38, 79]],
#
#        [[38, 77]],
#
#        [[38, 79]],
#
#        [[37, 80]],
#
#        [[37, 82]],
#
#        [[37, 80]],
#
#        [[38, 79]],
#
#        [[39, 80]],
#
#        [[39, 82]],
#
#        [[40, 83]],
#
#        [[40, 85]],
#
#        [[39, 86]],
#
#        [[39, 87]],
#
#        [[37, 89]],
#
#        [[37, 90]],
#
#        [[37, 89]],
#
#        [[39, 87]],
#
#        [[39, 86]],
#
#        [[40, 85]],
#
#        [[40, 84]],
#
#        [[41, 83]],
#
#        [[41, 82]],
#
#        [[42, 81]],
#
#        [[42, 80]],
#
#        [[43, 79]],
#
#        [[43, 78]],
#
#        [[44, 77]],
#
#        [[44, 76]],
#
#        [[45, 75]],
#
#        [[45, 74]],
#
#        [[47, 72]],
#
#        [[47, 71]],
#
#        [[48, 70]],
#
#        [[48, 69]],
#
#        [[49, 68]],
#
#        [[49, 67]],
#
#        [[50, 66]],
#
#        [[50, 65]],
#
#        [[52, 63]],
#
#        [[52, 62]],
#
#        [[53, 61]],
#
#        [[53, 60]],
#
#        [[54, 59]],
#
#        [[54, 58]],
#
#        [[55, 57]],
#
#        [[55, 56]],
#
#        [[57, 54]],
#
#        [[57, 53]],
#
#        [[58, 52]],
#
#        [[58, 51]],
#
#        [[59, 50]],
#
#        [[59, 49]],
#
#        [[61, 47]],
#
#        [[61, 46]],
#
#        [[62, 45]],
#
#        [[62, 44]],
#
#        [[63, 43]],
#
#        [[63, 42]],
#
#        [[65, 40]],
#
#        [[65, 39]],
#
#        [[66, 38]],
#
#        [[66, 37]],
#
#        [[68, 35]],
#
#        [[68, 34]],
#
#        [[69, 33]],
#
#        [[69, 32]],
#
#        [[70, 31]],
#
#        [[70, 30]],
#
#        [[72, 28]],
#
#        [[72, 27]],
#
#        [[73, 26]],
#
#        [[73, 25]],
#
#        [[75, 23]],
#
#        [[75, 22]]], dtype=int32), array([[[ 90,  17]],
#
#        [[ 89,  18]],
#
#        [[ 90,  17]],
#
#        [[ 93,  17]],
#
#        [[ 95,  19]],
#
#        [[102,  19]],
#
#        [[103,  20]],
#
#        [[109,  20]],
#
#        [[110,  21]],
#
#        [[116,  21]],
#
#        [[117,  22]],
#
#        [[120,  22]],
#
#        [[117,  22]],
#
#        [[116,  21]],
#
#        [[110,  21]],
#
#        [[109,  20]],
#
#        [[103,  20]],
#
#        [[102,  19]],
#
#        [[ 96,  19]],
#
#        [[ 95,  18]],
#
#        [[ 94,  18]],
#
#        [[ 93,  17]]], dtype=int32), array([[[ 84,  16]],
#
#        [[ 83,  17]],
#
#        [[ 78,  17]],
#
#        [[ 78,  18]],
#
#        [[ 77,  19]],
#
#        [[ 79,  17]],
#
#        [[ 80,  18]],
#
#        [[ 80,  19]],
#
#        [[ 79,  20]],
#
#        [[ 79,  21]],
#
#        [[ 77,  23]],
#
#        [[ 77,  24]],
#
#        [[ 76,  25]],
#
#        [[ 76,  26]],
#
#        [[ 74,  28]],
#
#        [[ 74,  29]],
#
#        [[ 72,  31]],
#
#        [[ 72,  32]],
#
#        [[ 71,  33]],
#
#        [[ 71,  34]],
#
#        [[ 70,  35]],
#
#        [[ 70,  36]],
#
#        [[ 68,  38]],
#
#        [[ 68,  39]],
#
#        [[ 67,  40]],
#
#        [[ 67,  41]],
#
#        [[ 66,  42]],
#
#        [[ 66,  43]],
#
#        [[ 65,  44]],
#
#        [[ 65,  45]],
#
#        [[ 63,  47]],
#
#        [[ 63,  48]],
#
#        [[ 62,  49]],
#
#        [[ 62,  50]],
#
#        [[ 61,  51]],
#
#        [[ 61,  52]],
#
#        [[ 59,  54]],
#
#        [[ 59,  55]],
#
#        [[ 58,  56]],
#
#        [[ 58,  57]],
#
#        [[ 57,  58]],
#
#        [[ 57,  59]],
#
#        [[ 55,  61]],
#
#        [[ 55,  62]],
#
#        [[ 54,  63]],
#
#        [[ 54,  64]],
#
#        [[ 52,  66]],
#
#        [[ 52,  67]],
#
#        [[ 51,  68]],
#
#        [[ 51,  69]],
#
#        [[ 50,  70]],
#
#        [[ 50,  71]],
#
#        [[ 49,  72]],
#
#        [[ 49,  73]],
#
#        [[ 48,  74]],
#
#        [[ 48,  75]],
#
#        [[ 47,  76]],
#
#        [[ 47,  77]],
#
#        [[ 45,  79]],
#
#        [[ 45,  81]],
#
#        [[ 43,  83]],
#
#        [[ 43,  84]],
#
#        [[ 42,  85]],
#
#        [[ 42,  86]],
#
#        [[ 41,  87]],
#
#        [[ 41,  88]],
#
#        [[ 40,  89]],
#
#        [[ 40,  90]],
#
#        [[ 39,  91]],
#
#        [[ 39,  92]],
#
#        [[ 38,  93]],
#
#        [[ 38,  94]],
#
#        [[ 37,  95]],
#
#        [[ 37,  96]],
#
#        [[ 36,  97]],
#
#        [[ 36,  98]],
#
#        [[ 35,  99]],
#
#        [[ 35, 100]],
#
#        [[ 34, 101]],
#
#        [[ 34, 102]],
#
#        [[ 33, 103]],
#
#        [[ 33, 104]],
#
#        [[ 32, 105]],
#
#        [[ 32, 106]],
#
#        [[ 31, 107]],
#
#        [[ 31, 109]],
#
#        [[ 29, 111]],
#
#        [[ 29, 112]],
#
#        [[ 28, 113]],
#
#        [[ 28, 114]],
#
#        [[ 27, 115]],
#
#        [[ 27, 117]],
#
#        [[ 26, 118]],
#
#        [[ 26, 119]],
#
#        [[ 25, 120]],
#
#        [[ 25, 121]],
#
#        [[ 24, 122]],
#
#        [[ 24, 123]],
#
#        [[ 23, 124]],
#
#        [[ 23, 125]],
#
#        [[ 22, 126]],
#
#        [[ 22, 127]],
#
#        [[ 21, 128]],
#
#        [[ 21, 129]],
#
#        [[ 20, 130]],
#
#        [[ 20, 131]],
#
#        [[ 19, 132]],
#
#        [[ 19, 133]],
#
#        [[ 18, 134]],
#
#        [[ 18, 138]],
#
#        [[ 22, 138]],
#
#        [[ 23, 139]],
#
#        [[ 28, 139]],
#
#        [[ 29, 140]],
#
#        [[ 32, 140]],
#
#        [[ 33, 141]],
#
#        [[ 38, 141]],
#
#        [[ 39, 142]],
#
#        [[ 43, 142]],
#
#        [[ 44, 143]],
#
#        [[ 48, 143]],
#
#        [[ 49, 144]],
#
#        [[ 53, 144]],
#
#        [[ 54, 145]],
#
#        [[ 59, 145]],
#
#        [[ 59, 144]],
#
#        [[ 60, 143]],
#
#        [[ 60, 142]],
#
#        [[ 61, 141]],
#
#        [[ 62, 142]],
#
#        [[ 62, 143]],
#
#        [[ 62, 142]],
#
#        [[ 63, 141]],
#
#        [[ 64, 142]],
#
#        [[ 64, 143]],
#
#        [[ 64, 142]],
#
#        [[ 63, 141]],
#
#        [[ 63, 139]],
#
#        [[ 64, 138]],
#
#        [[ 64, 137]],
#
#        [[ 65, 136]],
#
#        [[ 66, 137]],
#
#        [[ 66, 138]],
#
#        [[ 67, 139]],
#
#        [[ 67, 141]],
#
#        [[ 66, 142]],
#
#        [[ 66, 143]],
#
#        [[ 66, 142]],
#
#        [[ 67, 141]],
#
#        [[ 67, 139]],
#
#        [[ 68, 138]],
#
#        [[ 68, 137]],
#
#        [[ 69, 136]],
#
#        [[ 69, 134]],
#
#        [[ 70, 133]],
#
#        [[ 71, 134]],
#
#        [[ 73, 134]],
#
#        [[ 74, 135]],
#
#        [[ 74, 137]],
#
#        [[ 73, 138]],
#
#        [[ 73, 139]],
#
#        [[ 73, 138]],
#
#        [[ 74, 137]],
#
#        [[ 75, 138]],
#
#        [[ 75, 140]],
#
#        [[ 74, 141]],
#
#        [[ 74, 142]],
#
#        [[ 74, 141]],
#
#        [[ 75, 140]],
#
#        [[ 75, 138]],
#
#        [[ 76, 137]],
#
#        [[ 76, 136]],
#
#        [[ 77, 135]],
#
#        [[ 80, 135]],
#
#        [[ 78, 135]],
#
#        [[ 77, 134]],
#
#        [[ 78, 133]],
#
#        [[ 78, 131]],
#
#        [[ 79, 130]],
#
#        [[ 79, 128]],
#
#        [[ 80, 127]],
#
#        [[ 80, 126]],
#
#        [[ 81, 125]],
#
#        [[ 85, 125]],
#
#        [[ 86, 126]],
#
#        [[ 85, 127]],
#
#        [[ 85, 128]],
#
#        [[ 85, 127]],
#
#        [[ 86, 126]],
#
#        [[ 87, 127]],
#
#        [[ 87, 128]],
#
#        [[ 87, 127]],
#
#        [[ 88, 126]],
#
#        [[ 88, 124]],
#
#        [[ 89, 123]],
#
#        [[ 90, 124]],
#
#        [[ 90, 127]],
#
#        [[ 89, 128]],
#
#        [[ 89, 129]],
#
#        [[ 88, 130]],
#
#        [[ 88, 131]],
#
#        [[ 87, 132]],
#
#        [[ 86, 131]],
#
#        [[ 86, 130]],
#
#        [[ 86, 131]],
#
#        [[ 87, 132]],
#
#        [[ 87, 135]],
#
#        [[ 86, 136]],
#
#        [[ 86, 137]],
#
#        [[ 85, 138]],
#
#        [[ 85, 139]],
#
#        [[ 84, 140]],
#
#        [[ 84, 142]],
#
#        [[ 83, 143]],
#
#        [[ 82, 142]],
#
#        [[ 82, 140]],
#
#        [[ 81, 139]],
#
#        [[ 80, 140]],
#
#        [[ 80, 142]],
#
#        [[ 79, 143]],
#
#        [[ 79, 144]],
#
#        [[ 78, 145]],
#
#        [[ 78, 147]],
#
#        [[ 78, 146]],
#
#        [[ 79, 145]],
#
#        [[ 80, 146]],
#
#        [[ 80, 147]],
#
#        [[ 80, 146]],
#
#        [[ 81, 145]],
#
#        [[ 82, 146]],
#
#        [[ 82, 148]],
#
#        [[ 81, 149]],
#
#        [[ 76, 149]],
#
#        [[ 75, 148]],
#
#        [[ 71, 148]],
#
#        [[ 70, 147]],
#
#        [[ 65, 147]],
#
#        [[ 64, 146]],
#
#        [[ 62, 146]],
#
#        [[ 61, 145]],
#
#        [[ 61, 146]],
#
#        [[ 64, 146]],
#
#        [[ 65, 147]],
#
#        [[ 70, 147]],
#
#        [[ 71, 148]],
#
#        [[ 75, 148]],
#
#        [[ 76, 149]],
#
#        [[ 82, 149]],
#
#        [[ 83, 150]],
#
#        [[ 88, 150]],
#
#        [[ 89, 151]],
#
#        [[ 94, 151]],
#
#        [[ 95, 152]],
#
#        [[ 99, 152]],
#
#        [[100, 153]],
#
#        [[105, 153]],
#
#        [[106, 154]],
#
#        [[111, 154]],
#
#        [[112, 155]],
#
#        [[118, 155]],
#
#        [[119, 156]],
#
#        [[123, 156]],
#
#        [[124, 157]],
#
#        [[130, 157]],
#
#        [[131, 158]],
#
#        [[136, 158]],
#
#        [[137, 159]],
#
#        [[143, 159]],
#
#        [[144, 160]],
#
#        [[152, 160]],
#
#        [[152, 158]],
#
#        [[153, 157]],
#
#        [[153, 154]],
#
#        [[154, 153]],
#
#        [[154, 151]],
#
#        [[155, 150]],
#
#        [[155, 147]],
#
#        [[156, 146]],
#
#        [[156, 144]],
#
#        [[157, 143]],
#
#        [[157, 140]],
#
#        [[158, 139]],
#
#        [[158, 136]],
#
#        [[159, 135]],
#
#        [[159, 132]],
#
#        [[160, 131]],
#
#        [[160, 129]],
#
#        [[161, 128]],
#
#        [[161, 125]],
#
#        [[162, 124]],
#
#        [[162, 122]],
#
#        [[163, 121]],
#
#        [[163, 119]],
#
#        [[164, 118]],
#
#        [[164, 115]],
#
#        [[165, 114]],
#
#        [[165, 111]],
#
#        [[166, 110]],
#
#        [[166, 108]],
#
#        [[167, 107]],
#
#        [[167, 105]],
#
#        [[168, 104]],
#
#        [[168, 101]],
#
#        [[169, 100]],
#
#        [[169,  98]],
#
#        [[170,  97]],
#
#        [[170,  95]],
#
#        [[171,  94]],
#
#        [[171,  91]],
#
#        [[172,  90]],
#
#        [[172,  88]],
#
#        [[173,  87]],
#
#        [[173,  85]],
#
#        [[174,  84]],
#
#        [[174,  81]],
#
#        [[175,  80]],
#
#        [[175,  78]],
#
#        [[176,  77]],
#
#        [[176,  75]],
#
#        [[177,  74]],
#
#        [[177,  71]],
#
#        [[178,  70]],
#
#        [[178,  68]],
#
#        [[179,  67]],
#
#        [[179,  65]],
#
#        [[180,  64]],
#
#        [[180,  61]],
#
#        [[181,  60]],
#
#        [[181,  58]],
#
#        [[182,  57]],
#
#        [[182,  55]],
#
#        [[183,  54]],
#
#        [[183,  52]],
#
#        [[184,  51]],
#
#        [[184,  49]],
#
#        [[185,  48]],
#
#        [[185,  46]],
#
#        [[186,  45]],
#
#        [[186,  42]],
#
#        [[187,  41]],
#
#        [[187,  39]],
#
#        [[188,  38]],
#
#        [[188,  35]],
#
#        [[186,  35]],
#
#        [[185,  34]],
#
#        [[178,  34]],
#
#        [[177,  33]],
#
#        [[171,  33]],
#
#        [[170,  32]],
#
#        [[166,  32]],
#
#        [[165,  31]],
#
#        [[159,  31]],
#
#        [[158,  30]],
#
#        [[152,  30]],
#
#        [[151,  29]],
#
#        [[145,  29]],
#
#        [[144,  28]],
#
#        [[139,  28]],
#
#        [[138,  27]],
#
#        [[137,  28]],
#
#        [[136,  27]],
#
#        [[134,  27]],
#
#        [[134,  28]],
#
#        [[133,  29]],
#
#        [[132,  28]],
#
#        [[132,  27]],
#
#        [[131,  27]],
#
#        [[130,  26]],
#
#        [[125,  26]],
#
#        [[124,  25]],
#
#        [[116,  25]],
#
#        [[115,  24]],
#
#        [[110,  24]],
#
#        [[109,  23]],
#
#        [[104,  23]],
#
#        [[103,  22]],
#
#        [[ 98,  22]],
#
#        [[ 97,  21]],
#
#        [[ 92,  21]],
#
#        [[ 91,  20]],
#
#        [[ 83,  20]],
#
#        [[ 82,  19]],
#
#        [[ 81,  19]],
#
#        [[ 80,  18]],
#
#        [[ 81,  17]],
#
#        [[ 83,  17]]], dtype=int32), array([[[106, 147]],
#
#        [[107, 146]],
#
#        [[108, 147]],
#
#        [[108, 149]],
#
#        [[107, 150]],
#
#        [[106, 149]]], dtype=int32), array([[[ 82, 146]],
#
#        [[ 83, 145]],
#
#        [[ 84, 146]],
#
#        [[ 84, 148]],
#
#        [[ 83, 149]],
#
#        [[ 82, 148]]], dtype=int32), array([[[ 87, 145]],
#
#        [[ 88, 144]],
#
#        [[ 89, 145]],
#
#        [[ 89, 146]],
#
#        [[ 88, 147]],
#
#        [[ 87, 146]]], dtype=int32), array([[[109, 144]],
#
#        [[110, 143]],
#
#        [[111, 144]],
#
#        [[111, 146]],
#
#        [[110, 147]],
#
#        [[109, 146]]], dtype=int32), array([[[107, 144]],
#
#        [[108, 143]],
#
#        [[109, 144]],
#
#        [[109, 146]],
#
#        [[108, 147]],
#
#        [[107, 146]]], dtype=int32), array([[[ 81, 143]],
#
#        [[ 82, 142]],
#
#        [[ 83, 143]],
#
#        [[ 83, 145]],
#
#        [[ 82, 146]],
#
#        [[ 81, 145]]], dtype=int32), array([[[ 79, 143]],
#
#        [[ 80, 142]],
#
#        [[ 81, 143]],
#
#        [[ 81, 145]],
#
#        [[ 80, 146]],
#
#        [[ 79, 145]]], dtype=int32), array([[[ 84, 141]],
#
#        [[ 85, 140]],
#
#        [[ 86, 141]],
#
#        [[ 86, 143]],
#
#        [[ 85, 144]],
#
#        [[ 85, 145]],
#
#        [[ 84, 146]],
#
#        [[ 83, 145]],
#
#        [[ 83, 143]],
#
#        [[ 84, 142]]], dtype=int32), array([[[ 80, 140]],
#
#        [[ 81, 139]],
#
#        [[ 82, 140]],
#
#        [[ 82, 142]],
#
#        [[ 81, 143]],
#
#        [[ 80, 142]]], dtype=int32), array([[[ 97, 139]],
#
#        [[ 98, 138]],
#
#        [[ 99, 139]],
#
#        [[ 98, 140]]], dtype=int32), array([[[ 93, 139]],
#
#        [[ 94, 138]],
#
#        [[ 96, 138]],
#
#        [[ 97, 139]],
#
#        [[ 96, 140]],
#
#        [[ 94, 140]]], dtype=int32), array([[[ 87, 139]],
#
#        [[ 88, 138]],
#
#        [[ 89, 139]],
#
#        [[ 89, 140]],
#
#        [[ 90, 141]],
#
#        [[ 90, 143]],
#
#        [[ 89, 144]],
#
#        [[ 88, 144]],
#
#        [[ 87, 145]],
#
#        [[ 87, 146]],
#
#        [[ 86, 147]],
#
#        [[ 87, 146]],
#
#        [[ 88, 147]],
#
#        [[ 88, 148]],
#
#        [[ 88, 147]],
#
#        [[ 89, 146]],
#
#        [[ 89, 144]],
#
#        [[ 90, 143]],
#
#        [[ 90, 142]],
#
#        [[ 91, 141]],
#
#        [[ 91, 140]],
#
#        [[ 92, 139]],
#
#        [[ 93, 139]],
#
#        [[ 94, 140]],
#
#        [[ 95, 140]],
#
#        [[ 96, 141]],
#
#        [[ 96, 142]],
#
#        [[ 95, 143]],
#
#        [[ 95, 144]],
#
#        [[ 95, 143]],
#
#        [[ 96, 142]],
#
#        [[ 96, 141]],
#
#        [[ 97, 140]],
#
#        [[100, 140]],
#
#        [[101, 141]],
#
#        [[103, 141]],
#
#        [[104, 142]],
#
#        [[103, 143]],
#
#        [[103, 144]],
#
#        [[103, 143]],
#
#        [[104, 142]],
#
#        [[105, 143]],
#
#        [[105, 144]],
#
#        [[105, 143]],
#
#        [[104, 142]],
#
#        [[104, 140]],
#
#        [[105, 139]],
#
#        [[106, 140]],
#
#        [[106, 141]],
#
#        [[106, 140]],
#
#        [[107, 139]],
#
#        [[108, 140]],
#
#        [[108, 143]],
#
#        [[107, 144]],
#
#        [[107, 145]],
#
#        [[106, 146]],
#
#        [[106, 148]],
#
#        [[105, 149]],
#
#        [[104, 148]],
#
#        [[104, 146]],
#
#        [[104, 148]],
#
#        [[105, 149]],
#
#        [[105, 151]],
#
#        [[105, 150]],
#
#        [[106, 149]],
#
#        [[107, 150]],
#
#        [[107, 152]],
#
#        [[106, 153]],
#
#        [[100, 153]],
#
#        [[ 99, 152]],
#
#        [[ 95, 152]],
#
#        [[ 94, 151]],
#
#        [[ 89, 151]],
#
#        [[ 88, 150]],
#
#        [[ 84, 150]],
#
#        [[ 83, 149]],
#
#        [[ 84, 148]],
#
#        [[ 84, 146]],
#
#        [[ 85, 145]],
#
#        [[ 85, 144]],
#
#        [[ 86, 143]],
#
#        [[ 86, 141]],
#
#        [[ 87, 140]]], dtype=int32), array([[[ 61, 139]],
#
#        [[ 62, 138]],
#
#        [[ 63, 139]],
#
#        [[ 63, 141]],
#
#        [[ 62, 142]],
#
#        [[ 61, 141]]], dtype=int32), array([[[109, 138]],
#
#        [[110, 137]],
#
#        [[111, 138]],
#
#        [[111, 139]],
#
#        [[111, 138]],
#
#        [[112, 137]],
#
#        [[113, 138]],
#
#        [[113, 140]],
#
#        [[112, 141]],
#
#        [[112, 142]],
#
#        [[113, 143]],
#
#        [[113, 147]],
#
#        [[112, 148]],
#
#        [[112, 149]],
#
#        [[111, 150]],
#
#        [[110, 149]],
#
#        [[110, 147]],
#
#        [[111, 146]],
#
#        [[111, 144]],
#
#        [[110, 143]],
#
#        [[110, 141]],
#
#        [[110, 143]],
#
#        [[109, 144]],
#
#        [[108, 143]],
#
#        [[108, 140]],
#
#        [[109, 139]]], dtype=int32), array([[[105, 137]],
#
#        [[106, 136]],
#
#        [[107, 137]],
#
#        [[107, 139]],
#
#        [[106, 140]],
#
#        [[105, 139]]], dtype=int32), array([[[ 66, 137]],
#
#        [[ 67, 136]],
#
#        [[ 68, 137]],
#
#        [[ 68, 138]],
#
#        [[ 67, 139]],
#
#        [[ 66, 138]]], dtype=int32), array([[[ 62, 137]],
#
#        [[ 63, 136]],
#
#        [[ 64, 137]],
#
#        [[ 64, 138]],
#
#        [[ 63, 139]],
#
#        [[ 62, 138]]], dtype=int32), array([[[ 86, 136]],
#
#        [[ 87, 135]],
#
#        [[ 88, 136]],
#
#        [[ 88, 138]],
#
#        [[ 87, 139]],
#
#        [[ 87, 140]],
#
#        [[ 86, 141]],
#
#        [[ 85, 140]],
#
#        [[ 85, 138]],
#
#        [[ 86, 137]]], dtype=int32), array([[[ 74, 136]],
#
#        [[ 75, 135]],
#
#        [[ 76, 136]],
#
#        [[ 76, 137]],
#
#        [[ 75, 138]],
#
#        [[ 74, 137]]], dtype=int32), array([[[ 39, 136]],
#
#        [[ 40, 135]],
#
#        [[ 41, 136]],
#
#        [[ 41, 137]],
#
#        [[ 40, 138]],
#
#        [[ 39, 137]]], dtype=int32), array([[[138, 135]],
#
#        [[139, 134]],
#
#        [[140, 135]],
#
#        [[140, 137]],
#
#        [[139, 138]],
#
#        [[138, 137]]], dtype=int32), array([[[136, 135]],
#
#        [[137, 134]],
#
#        [[138, 135]],
#
#        [[138, 137]],
#
#        [[137, 138]],
#
#        [[136, 137]]], dtype=int32), array([[[110, 135]],
#
#        [[111, 134]],
#
#        [[112, 135]],
#
#        [[112, 137]],
#
#        [[111, 138]],
#
#        [[110, 137]]], dtype=int32), array([[[ 51, 135]],
#
#        [[ 52, 134]],
#
#        [[ 53, 135]],
#
#        [[ 53, 137]],
#
#        [[ 52, 138]],
#
#        [[ 52, 139]],
#
#        [[ 51, 140]],
#
#        [[ 50, 139]],
#
#        [[ 50, 137]],
#
#        [[ 51, 136]]], dtype=int32), array([[[ 91, 133]],
#
#        [[ 92, 132]],
#
#        [[ 93, 133]],
#
#        [[ 93, 135]],
#
#        [[ 92, 136]],
#
#        [[ 91, 135]]], dtype=int32), array([[[ 89, 133]],
#
#        [[ 90, 132]],
#
#        [[ 91, 133]],
#
#        [[ 91, 135]],
#
#        [[ 92, 136]],
#
#        [[ 92, 137]],
#
#        [[ 91, 138]],
#
#        [[ 90, 137]],
#
#        [[ 91, 138]],
#
#        [[ 91, 140]],
#
#        [[ 90, 141]],
#
#        [[ 89, 140]],
#
#        [[ 89, 139]],
#
#        [[ 88, 138]],
#
#        [[ 88, 136]],
#
#        [[ 89, 135]]], dtype=int32), array([[[ 87, 133]],
#
#        [[ 88, 132]],
#
#        [[ 89, 133]],
#
#        [[ 89, 135]],
#
#        [[ 88, 136]],
#
#        [[ 87, 135]]], dtype=int32), array([[[ 75, 133]],
#
#        [[ 76, 132]],
#
#        [[ 77, 133]],
#
#        [[ 77, 135]],
#
#        [[ 76, 136]],
#
#        [[ 75, 135]]], dtype=int32), array([[[ 62, 133]],
#
#        [[ 63, 132]],
#
#        [[ 64, 133]],
#
#        [[ 63, 134]]], dtype=int32), array([[[ 60, 133]],
#
#        [[ 61, 132]],
#
#        [[ 62, 133]],
#
#        [[ 61, 134]]], dtype=int32), array([[[111, 132]],
#
#        [[112, 131]],
#
#        [[113, 132]],
#
#        [[113, 133]],
#
#        [[113, 132]],
#
#        [[114, 131]],
#
#        [[115, 132]],
#
#        [[115, 134]],
#
#        [[114, 135]],
#
#        [[114, 137]],
#
#        [[113, 138]],
#
#        [[112, 137]],
#
#        [[112, 135]],
#
#        [[111, 134]]], dtype=int32), array([[[135, 131]],
#
#        [[136, 130]],
#
#        [[137, 131]],
#
#        [[137, 133]],
#
#        [[136, 134]],
#
#        [[135, 133]]], dtype=int32), array([[[ 90, 131]],
#
#        [[ 91, 130]],
#
#        [[ 92, 131]],
#
#        [[ 92, 132]],
#
#        [[ 91, 133]],
#
#        [[ 90, 132]]], dtype=int32), array([[[ 76, 131]],
#
#        [[ 77, 130]],
#
#        [[ 78, 131]],
#
#        [[ 78, 132]],
#
#        [[ 77, 133]],
#
#        [[ 76, 132]]], dtype=int32), array([[[ 88, 130]],
#
#        [[ 89, 129]],
#
#        [[ 90, 130]],
#
#        [[ 90, 132]],
#
#        [[ 89, 133]],
#
#        [[ 88, 132]]], dtype=int32), array([[[112, 129]],
#
#        [[113, 128]],
#
#        [[114, 129]],
#
#        [[114, 131]],
#
#        [[113, 132]],
#
#        [[112, 131]]], dtype=int32), array([[[ 67, 129]],
#
#        [[ 68, 128]],
#
#        [[ 69, 129]],
#
#        [[ 69, 130]],
#
#        [[ 69, 129]],
#
#        [[ 70, 128]],
#
#        [[ 71, 129]],
#
#        [[ 71, 131]],
#
#        [[ 70, 132]],
#
#        [[ 70, 133]],
#
#        [[ 69, 134]],
#
#        [[ 68, 133]],
#
#        [[ 68, 132]],
#
#        [[ 67, 131]]], dtype=int32), array([[[ 65, 129]],
#
#        [[ 66, 128]],
#
#        [[ 67, 129]],
#
#        [[ 67, 131]],
#
#        [[ 66, 132]],
#
#        [[ 66, 133]],
#
#        [[ 66, 132]],
#
#        [[ 67, 131]],
#
#        [[ 68, 132]],
#
#        [[ 68, 133]],
#
#        [[ 69, 134]],
#
#        [[ 69, 136]],
#
#        [[ 68, 137]],
#
#        [[ 67, 136]],
#
#        [[ 67, 135]],
#
#        [[ 67, 136]],
#
#        [[ 66, 137]],
#
#        [[ 65, 136]],
#
#        [[ 65, 135]],
#
#        [[ 65, 136]],
#
#        [[ 64, 137]],
#
#        [[ 63, 136]],
#
#        [[ 63, 134]],
#
#        [[ 64, 133]],
#
#        [[ 64, 131]],
#
#        [[ 65, 130]]], dtype=int32), array([[[ 63, 129]],
#
#        [[ 64, 128]],
#
#        [[ 65, 129]],
#
#        [[ 65, 130]],
#
#        [[ 64, 131]],
#
#        [[ 63, 130]]], dtype=int32), array([[[ 89, 128]],
#
#        [[ 90, 127]],
#
#        [[ 91, 128]],
#
#        [[ 91, 129]],
#
#        [[ 90, 130]],
#
#        [[ 89, 129]]], dtype=int32), array([[[ 77, 128]],
#
#        [[ 78, 127]],
#
#        [[ 79, 128]],
#
#        [[ 79, 130]],
#
#        [[ 78, 131]],
#
#        [[ 77, 130]]], dtype=int32), array([[[ 70, 127]],
#
#        [[ 71, 126]],
#
#        [[ 72, 127]],
#
#        [[ 72, 128]],
#
#        [[ 71, 129]],
#
#        [[ 70, 128]]], dtype=int32), array([[[ 68, 127]],
#
#        [[ 69, 126]],
#
#        [[ 70, 127]],
#
#        [[ 70, 128]],
#
#        [[ 69, 129]],
#
#        [[ 68, 128]]], dtype=int32), array([[[ 66, 127]],
#
#        [[ 67, 126]],
#
#        [[ 68, 127]],
#
#        [[ 68, 128]],
#
#        [[ 67, 129]],
#
#        [[ 66, 128]]], dtype=int32), array([[[ 47, 127]],
#
#        [[ 48, 126]],
#
#        [[ 49, 127]],
#
#        [[ 49, 128]],
#
#        [[ 48, 129]],
#
#        [[ 47, 128]]], dtype=int32), array([[[113, 126]],
#
#        [[114, 125]],
#
#        [[115, 126]],
#
#        [[115, 128]],
#
#        [[114, 129]],
#
#        [[113, 128]]], dtype=int32), array([[[ 86, 125]],
#
#        [[ 87, 124]],
#
#        [[ 88, 125]],
#
#        [[ 88, 126]],
#
#        [[ 87, 127]],
#
#        [[ 86, 126]]], dtype=int32), array([[[ 69, 125]],
#
#        [[ 70, 124]],
#
#        [[ 71, 125]],
#
#        [[ 71, 126]],
#
#        [[ 70, 127]],
#
#        [[ 69, 126]]], dtype=int32), array([[[ 46, 125]],
#
#        [[ 47, 124]],
#
#        [[ 48, 125]],
#
#        [[ 48, 126]],
#
#        [[ 47, 127]],
#
#        [[ 46, 126]]], dtype=int32), array([[[ 40, 125]],
#
#        [[ 41, 124]],
#
#        [[ 42, 125]],
#
#        [[ 42, 126]],
#
#        [[ 41, 127]],
#
#        [[ 40, 126]]], dtype=int32), array([[[102, 124]],
#
#        [[103, 123]],
#
#        [[104, 124]],
#
#        [[104, 126]],
#
#        [[103, 127]],
#
#        [[102, 126]]], dtype=int32), array([[[ 84, 124]],
#
#        [[ 85, 123]],
#
#        [[ 86, 124]],
#
#        [[ 85, 125]]], dtype=int32), array([[[ 73, 124]],
#
#        [[ 74, 123]],
#
#        [[ 75, 124]],
#
#        [[ 77, 124]],
#
#        [[ 78, 125]],
#
#        [[ 78, 127]],
#
#        [[ 77, 128]],
#
#        [[ 77, 130]],
#
#        [[ 76, 131]],
#
#        [[ 76, 132]],
#
#        [[ 75, 133]],
#
#        [[ 75, 134]],
#
#        [[ 74, 135]],
#
#        [[ 73, 134]],
#
#        [[ 71, 134]],
#
#        [[ 70, 133]],
#
#        [[ 70, 132]],
#
#        [[ 71, 131]],
#
#        [[ 71, 129]],
#
#        [[ 72, 128]],
#
#        [[ 72, 127]],
#
#        [[ 73, 126]]], dtype=int32), array([[[ 67, 124]],
#
#        [[ 68, 123]],
#
#        [[ 69, 124]],
#
#        [[ 69, 126]],
#
#        [[ 68, 127]],
#
#        [[ 67, 126]]], dtype=int32), array([[[118, 123]],
#
#        [[119, 122]],
#
#        [[120, 123]],
#
#        [[120, 125]],
#
#        [[119, 126]],
#
#        [[118, 125]]], dtype=int32), array([[[114, 123]],
#
#        [[115, 122]],
#
#        [[116, 123]],
#
#        [[116, 125]],
#
#        [[115, 126]],
#
#        [[114, 125]]], dtype=int32), array([[[ 81, 123]],
#
#        [[ 82, 122]],
#
#        [[ 84, 124]],
#
#        [[ 83, 125]],
#
#        [[ 82, 125]],
#
#        [[ 81, 124]]], dtype=int32), array([[[ 66, 123]],
#
#        [[ 67, 122]],
#
#        [[ 68, 123]],
#
#        [[ 67, 124]]], dtype=int32), array([[[ 56, 123]],
#
#        [[ 57, 122]],
#
#        [[ 58, 123]],
#
#        [[ 58, 124]],
#
#        [[ 57, 125]],
#
#        [[ 56, 124]]], dtype=int32), array([[[ 46, 122]],
#
#        [[ 47, 123]],
#
#        [[ 47, 124]],
#
#        [[ 46, 125]],
#
#        [[ 46, 126]],
#
#        [[ 45, 127]],
#
#        [[ 44, 126]],
#
#        [[ 44, 124]]], dtype=int32), array([[[ 91, 122]],
#
#        [[ 92, 121]],
#
#        [[ 93, 122]],
#
#        [[ 93, 124]],
#
#        [[ 92, 125]],
#
#        [[ 91, 124]]], dtype=int32), array([[[ 68, 122]],
#
#        [[ 69, 121]],
#
#        [[ 70, 122]],
#
#        [[ 70, 123]],
#
#        [[ 69, 124]],
#
#        [[ 68, 123]]], dtype=int32), array([[[140, 121]],
#
#        [[141, 120]],
#
#        [[143, 120]],
#
#        [[144, 121]],
#
#        [[143, 122]],
#
#        [[142, 122]],
#
#        [[142, 123]],
#
#        [[143, 122]],
#
#        [[144, 123]],
#
#        [[144, 124]],
#
#        [[143, 125]],
#
#        [[143, 128]],
#
#        [[142, 129]],
#
#        [[142, 130]],
#
#        [[141, 131]],
#
#        [[141, 133]],
#
#        [[140, 134]],
#
#        [[139, 133]],
#
#        [[139, 132]],
#
#        [[139, 134]],
#
#        [[138, 135]],
#
#        [[137, 134]],
#
#        [[137, 131]],
#
#        [[138, 130]],
#
#        [[138, 128]],
#
#        [[139, 127]],
#
#        [[139, 125]],
#
#        [[140, 124]],
#
#        [[141, 125]],
#
#        [[141, 127]],
#
#        [[141, 125]],
#
#        [[140, 124]]], dtype=int32), array([[[117, 121]],
#
#        [[118, 120]],
#
#        [[119, 121]],
#
#        [[119, 122]],
#
#        [[118, 123]],
#
#        [[117, 122]]], dtype=int32), array([[[103, 121]],
#
#        [[104, 120]],
#
#        [[105, 121]],
#
# ...
#
#        [[173,  33]],
#
#        [[169,  33]],
#
#        [[168,  32]],
#
#        [[162,  32]],
#
#        [[161,  31]],
#
#        [[155,  31]],
#
#        [[154,  30]],
#
#        [[149,  30]],
#
#        [[148,  29]],
#
#        [[141,  29]],
#
#        [[140,  28]]], dtype=int32), array([[[150, 161]],
#
#        [[151, 160]],
#
#        [[152, 160]],
#
#        [[153, 161]],
#
#        [[152, 162]],
#
#        [[151, 162]]], dtype=int32), array([[[125, 152]],
#
#        [[126, 151]],
#
#        [[127, 152]],
#
#        [[127, 155]],
#
#        [[126, 156]],
#
#        [[125, 155]]], dtype=int32), array([[[129, 147]],
#
#        [[130, 146]],
#
#        [[131, 147]],
#
#        [[131, 148]],
#
#        [[132, 149]],
#
#        [[132, 152]],
#
#        [[131, 153]],
#
#        [[130, 152]],
#
#        [[130, 150]],
#
#        [[130, 152]],
#
#        [[129, 153]],
#
#        [[128, 152]],
#
#        [[128, 149]],
#
#        [[129, 148]]], dtype=int32), array([[[134, 136]],
#
#        [[135, 135]],
#
#        [[136, 136]],
#
#        [[136, 138]],
#
#        [[135, 139]],
#
#        [[134, 138]]], dtype=int32), array([[[137, 126]],
#
#        [[138, 125]],
#
#        [[139, 126]],
#
#        [[139, 128]],
#
#        [[138, 129]],
#
#        [[137, 128]]], dtype=int32), array([[[138, 123]],
#
#        [[139, 122]],
#
#        [[140, 123]],
#
#        [[140, 125]],
#
#        [[139, 126]],
#
#        [[138, 125]]], dtype=int32), array([[[139, 120]],
#
#        [[140, 119]],
#
#        [[141, 120]],
#
#        [[141, 122]],
#
#        [[140, 123]],
#
#        [[139, 122]]], dtype=int32), array([[[140, 117]],
#
#        [[141, 116]],
#
#        [[142, 117]],
#
#        [[142, 119]],
#
#        [[141, 120]],
#
#        [[140, 119]]], dtype=int32), array([[[146, 110]],
#
#        [[147, 109]],
#
#        [[148, 110]],
#
#        [[148, 113]],
#
#        [[147, 114]],
#
#        [[146, 113]]], dtype=int32), array([[[144, 104]],
#
#        [[145, 103]],
#
#        [[146, 104]],
#
#        [[146, 106]],
#
#        [[145, 107]],
#
#        [[144, 106]]], dtype=int32), array([[[74, 25]],
#
#        [[73, 26]],
#
#        [[73, 27]],
#
#        [[72, 28]],
#
#        [[73, 27]],
#
#        [[73, 26]]], dtype=int32), array([[[191,  23]],
#
#        [[191,  25]],
#
#        [[190,  26]],
#
#        [[185,  26]],
#
#        [[191,  26]]], dtype=int32), array([[[80, 20]],
#
#        [[78, 22]],
#
#        [[78, 23]],
#
#        ...,
#
#        [[92, 21]],
#
#        [[87, 21]],
#
#        [[86, 20]]], dtype=int32), array([[[ 78,  18]],
#
#        [[ 77,  19]],
#
#        [[ 77,  20]],
#
#        [[ 76,  21]],
#
#        [[ 76,  22]],
#
#        [[ 75,  23]],
#
#        [[ 76,  22]],
#
#        [[ 76,  21]],
#
#        [[ 77,  20]],
#
#        [[ 77,  19]],
#
#        [[ 78,  18]],
#
#        [[ 93,  18]],
#
#        [[ 94,  19]],
#
#        [[ 96,  19]],
#
#        [[ 97,  20]],
#
#        [[103,  20]],
#
#        [[104,  21]],
#
#        [[111,  21]],
#
#        [[112,  22]],
#
#        [[117,  22]],
#
#        [[118,  23]],
#
#        [[125,  23]],
#
#        [[126,  24]],
#
#        [[131,  24]],
#
#        [[132,  25]],
#
#        [[139,  25]],
#
#        [[140,  26]],
#
#        [[145,  26]],
#
#        [[146,  27]],
#
#        [[153,  27]],
#
#        [[154,  28]],
#
#        [[161,  28]],
#
#        [[162,  29]],
#
#        [[170,  29]],
#
#        [[171,  30]],
#
#        [[179,  30]],
#
#        [[180,  31]],
#
#        [[184,  31]],
#
#        [[185,  32]],
#
#        [[189,  32]],
#
#        [[191,  34]],
#
#        [[191,  35]],
#
#        [[191,  33]],
#
#        [[190,  33]],
#
#        [[189,  32]],
#
#        [[185,  32]],
#
#        [[184,  31]],
#
#        [[180,  31]],
#
#        [[179,  30]],
#
#        [[171,  30]],
#
#        [[170,  29]],
#
#        [[162,  29]],
#
#        [[161,  28]],
#
#        [[154,  28]],
#
#        [[153,  27]],
#
#        [[146,  27]],
#
#        [[145,  26]],
#
#        [[140,  26]],
#
#        [[139,  25]],
#
#        [[133,  25]],
#
#        [[132,  24]],
#
#        [[126,  24]],
#
#        [[125,  23]],
#
#        [[118,  23]],
#
#        [[117,  22]],
#
#        [[112,  22]],
#
#        [[111,  21]],
#
#        [[104,  21]],
#
#        [[103,  20]],
#
#        [[ 97,  20]],
#
#        [[ 96,  19]],
#
#        [[ 94,  19]],
#
#        [[ 93,  18]]], dtype=int32), array([[[186,   0]],
#
#        [[185,   1]],
#
#        [[185,   2]],
#
#        [[184,   3]],
#
#        [[184,   5]],
#
#        [[183,   6]],
#
#        [[183,   7]],
#
#        [[182,   8]],
#
#        [[182,   9]],
#
#        [[181,  10]],
#
#        [[181,  11]],
#
#        [[180,  12]],
#
#        [[180,  14]],
#
#        [[180,  13]],
#
#        [[181,  12]],
#
#        [[182,  13]],
#
#        [[182,  15]],
#
#        [[181,  16]],
#
#        [[181,  17]],
#
#        [[180,  18]],
#
#        [[179,  17]],
#
#        [[179,  16]],
#
#        [[178,  17]],
#
#        [[177,  16]],
#
#        [[178,  17]],
#
#        [[178,  19]],
#
#        [[177,  20]],
#
#        [[177,  22]],
#
#        [[176,  23]],
#
#        [[176,  26]],
#
#        [[175,  27]],
#
#        [[174,  27]],
#
#        [[174,  28]],
#
#        [[175,  28]],
#
#        [[175,  27]],
#
#        [[176,  26]],
#
#        [[177,  26]],
#
#        [[178,  27]],
#
#        [[183,  27]],
#
#        [[184,  28]],
#
#        [[189,  28]],
#
#        [[190,  29]],
#
#        [[191,  29]],
#
#        [[190,  29]],
#
#        [[189,  28]],
#
#        [[184,  28]],
#
#        [[183,  27]],
#
#        [[178,  27]],
#
#        [[176,  25]],
#
#        [[176,  23]],
#
#        [[177,  22]],
#
#        [[178,  23]],
#
#        [[178,  24]],
#
#        [[179,  25]],
#
#        [[183,  25]],
#
#        [[179,  25]],
#
#        [[178,  24]],
#
#        [[179,  23]],
#
#        [[179,  20]],
#
#        [[180,  19]],
#
#        [[180,  18]],
#
#        [[181,  17]],
#
#        [[181,  16]],
#
#        [[182,  15]],
#
#        [[182,  13]],
#
#        [[183,  12]],
#
#        [[183,  11]],
#
#        [[184,  10]],
#
#        [[184,   8]],
#
#        [[185,   7]],
#
#        [[185,   6]],
#
#        [[186,   5]],
#
#        [[186,   3]],
#
#        [[187,   2]],
#
#        [[187,   1]],
#
#        [[188,   0]],
#
#        [[187,   1]]], dtype=int32), array([[[177,  20]],
#
#        [[178,  19]],
#
#        [[179,  20]],
#
#        [[179,  22]],
#
#        [[178,  23]],
#
#        [[177,  22]]], dtype=int32), array([[[178,  18]],
#
#        [[179,  17]],
#
#        [[180,  18]],
#
#        [[180,  19]],
#
#        [[179,  20]],
#
#        [[178,  19]]], dtype=int32), array([[[181,  11]],
#
#        [[182,  10]],
#
#        [[183,  11]],
#
#        [[183,  12]],
#
#        [[182,  13]],
#
#        [[181,  12]]], dtype=int32), array([[[182,   8]],
#
#        [[183,   7]],
#
#        [[184,   8]],
#
#        [[184,  10]],
#
#        [[183,  11]],
#
#        [[182,  10]]], dtype=int32), array([[[183,   6]],
#
#        [[184,   5]],
#
#        [[185,   6]],
#
#        [[185,   7]],
#
#        [[184,   8]],
#
#        [[183,   7]]], dtype=int32), array([[[184,   3]],
#
#        [[185,   2]],
#
#        [[186,   3]],
#
#        [[186,   5]],
#
#        [[185,   6]],
#
#        [[184,   5]]], dtype=int32), array([[[185,   1]],
#
#        [[186,   0]],
#
#        [[187,   1]],
#
#        [[187,   2]],
#
#        [[186,   3]],
#
#        [[185,   2]]], dtype=int32), array([[[ 46,   0]],
#
#        [[ 46,   9]],
#
#        [[ 47,  10]],
#
#        [[ 47,  14]],
#
#        [[ 48,  15]],
#
#        [[ 47,  16]],
#
#        [[ 47,  17]],
#
#        [[ 48,  18]],
#
#        [[ 48,  26]],
#
#        [[ 49,  27]],
#
#        [[ 49,  33]],
#
#        [[ 50,  34]],
#
#        [[ 50,  46]],
#
#        [[ 51,  47]],
#
#        [[ 51,  49]],
#
#        [[ 49,  51]],
#
#        [[ 21,  51]],
#
#        [[ 19,  49]],
#
#        [[ 17,  49]],
#
#        [[ 15,  51]],
#
#        [[ 14,  50]],
#
#        [[ 12,  50]],
#
#        [[ 11,  49]],
#
#        [[ 10,  49]],
#
#        [[  9,  48]],
#
#        [[  8,  49]],
#
#        [[  6,  49]],
#
#        [[  5,  50]],
#
#        [[  0,  50]],
#
#        [[  6,  50]],
#
#        [[  7,  51]],
#
#        [[ 10,  51]],
#
#        [[ 11,  50]],
#
#        [[ 14,  50]],
#
#        [[ 15,  51]],
#
#        [[ 16,  50]],
#
#        [[ 17,  50]],
#
#        [[ 18,  49]],
#
#        [[ 19,  50]],
#
#        [[ 20,  50]],
#
#        [[ 21,  51]],
#
#        [[ 49,  51]],
#
#        [[ 50,  50]],
#
#        [[ 51,  50]],
#
#        [[ 51,  47]],
#
#        [[ 50,  46]],
#
#        [[ 50,  34]],
#
#        [[ 49,  33]],
#
#        [[ 49,  27]],
#
#        [[ 48,  26]],
#
#        [[ 48,  24]],
#
#        [[ 50,  22]],
#
#        [[ 52,  22]],
#
#        [[ 53,  21]],
#
#        [[ 55,  21]],
#
#        [[ 56,  20]],
#
#        [[ 58,  20]],
#
#        [[ 60,  18]],
#
#        [[ 63,  18]],
#
#        [[ 64,  17]],
#
#        [[ 66,  17]],
#
#        [[ 67,  16]],
#
#        [[ 68,  16]],
#
#        [[ 69,  15]],
#
#        [[ 71,  15]],
#
#        [[ 72,  14]],
#
#        [[ 74,  14]],
#
#        [[ 75,  13]],
#
#        [[ 77,  13]],
#
#        [[ 78,  12]],
#
#        [[ 81,  12]],
#
#        [[ 82,  11]],
#
#        [[ 84,  11]],
#
#        [[ 85,  10]],
#
#        [[ 87,  10]],
#
#        [[ 88,   9]],
#
#        [[ 89,   9]],
#
#        [[ 90,   8]],
#
#        [[ 91,   8]],
#
#        [[ 92,   7]],
#
#        [[ 96,   7]],
#
#        [[ 97,   6]],
#
#        [[ 99,   6]],
#
#        [[101,   4]],
#
#        [[104,   4]],
#
#        [[105,   3]],
#
#        [[107,   3]],
#
#        [[108,   2]],
#
#        [[110,   2]],
#
#        [[111,   1]],
#
#        [[113,   1]],
#
#        [[114,   0]],
#
#        [[115,   0]],
#
#        [[113,   0]],
#
#        [[112,   1]],
#
#        [[110,   1]],
#
#        [[109,   2]],
#
#        [[108,   2]],
#
#        [[107,   3]],
#
#        [[105,   3]],
#
#        [[104,   4]],
#
#        [[101,   4]],
#
#        [[100,   5]],
#
#        [[ 99,   5]],
#
#        [[ 98,   6]],
#
#        [[ 97,   6]],
#
#        [[ 96,   7]],
#
#        [[ 91,   7]],
#
#        [[ 89,   9]],
#
#        [[ 87,   9]],
#
#        [[ 86,  10]],
#
#        [[ 85,  10]],
#
#        [[ 84,  11]],
#
#        [[ 82,  11]],
#
#        [[ 81,  12]],
#
#        [[ 78,  12]],
#
#        [[ 77,  13]],
#
#        [[ 75,  13]],
#
#        [[ 74,  14]],
#
#        [[ 72,  14]],
#
#        [[ 71,  15]],
#
#        [[ 69,  15]],
#
#        [[ 68,  16]],
#
#        [[ 67,  16]],
#
#        [[ 66,  17]],
#
#        [[ 64,  17]],
#
#        [[ 63,  18]],
#
#        [[ 59,  18]],
#
#        [[ 57,  20]],
#
#        [[ 56,  20]],
#
#        [[ 55,  21]],
#
#        [[ 52,  21]],
#
#        [[ 51,  22]],
#
#        [[ 50,  22]],
#
#        [[ 49,  23]],
#
#        [[ 48,  22]],
#
#        [[ 48,  18]],
#
#        [[ 47,  17]],
#
#        [[ 47,  16]],
#
#        [[ 49,  14]],
#
#        [[ 52,  14]],
#
#        [[ 53,  13]],
#
#        [[ 55,  13]],
#
#        [[ 56,  12]],
#
#        [[ 58,  12]],
#
#        [[ 59,  11]],
#
#        [[ 61,  11]],
#
#        [[ 62,  10]],
#
#        [[ 64,  10]],
#
#        [[ 65,   9]],
#
#        [[ 67,   9]],
#
#        [[ 68,   8]],
#
#        [[ 70,   8]],
#
#        [[ 71,   7]],
#
#        [[ 73,   7]],
#
#        [[ 74,   6]],
#
#        [[ 75,   6]],
#
#        [[ 76,   5]],
#
#        [[ 79,   5]],
#
#        [[ 80,   4]],
#
#        [[ 82,   4]],
#
#        [[ 83,   3]],
#
#        [[ 85,   3]],
#
#        [[ 86,   2]],
#
#        [[ 89,   2]],
#
#        [[ 90,   1]],
#
#        [[ 91,   1]],
#
#        [[ 92,   0]],
#
#        [[ 94,   0]],
#
#        [[ 92,   0]],
#
#        [[ 91,   1]],
#
#        [[ 90,   1]],
#
#        [[ 89,   2]],
#
#        [[ 86,   2]],
#
#        [[ 85,   3]],
#
#        [[ 83,   3]],
#
#        [[ 82,   4]],
#
#        [[ 80,   4]],
#
#        [[ 79,   5]],
#
#        [[ 76,   5]],
#
#        [[ 75,   6]],
#
#        [[ 74,   6]],
#
#        [[ 73,   7]],
#
#        [[ 71,   7]],
#
#        [[ 70,   8]],
#
#        [[ 68,   8]],
#
#        [[ 67,   9]],
#
#        [[ 65,   9]],
#
#        [[ 64,  10]],
#
#        [[ 62,  10]],
#
#        [[ 61,  11]],
#
#        [[ 59,  11]],
#
#        [[ 58,  12]],
#
#        [[ 56,  12]],
#
#        [[ 55,  13]],
#
#        [[ 53,  13]],
#
#        [[ 52,  14]],
#
#        [[ 48,  14]],
#
#        [[ 47,  13]],
#
#        [[ 47,  10]],
#
#        [[ 46,   9]]], dtype=int32), array([[[ 8, 49]],
#
#        [[ 9, 48]],
#
#        [[11, 50]],
#
#        [[10, 51]],
#
#        [[ 7, 51]],
#
#        [[ 6, 50]],
#
#        [[ 7, 49]]], dtype=int32)], array([[[  1,  -1,  -1,  -1],
#         [  5,   0,   2,  -1],
#         [  3,  -1,  -1,   1],
#         [  4,   2,  -1,   1],
#         [ -1,   3,  -1,   1],
#         [  7,   1,   6,  -1],
#         [ -1,  -1,  -1,   5],
#         [ 10,   5,   8,  -1],
#         [  9,  -1,  -1,   7],
#         [ -1,   8,  -1,   7],
#         [ 11,   7,  -1,  -1],
#         [ 27,  10,  12,  -1],
#         [ 13,  -1,  -1,  11],
#         [ 14,  12,  -1,  11],
#         [ 15,  13,  -1,  11],
#         [ 16,  14,  -1,  11],
#         [ 17,  15,  -1,  11],
#         [ 18,  16,  -1,  11],
#         [ 19,  17,  -1,  11],
#         [ 20,  18,  -1,  11],
#         [ 21,  19,  -1,  11],
#         [ 22,  20,  -1,  11],
#         [ 23,  21,  -1,  11],
#         [ 24,  22,  -1,  11],
#         [ 25,  23,  -1,  11],
#         [ 26,  24,  -1,  11],
#         [ -1,  25,  -1,  11],
#         [ 28,  11,  -1,  -1],
#         [ 31,  27,  29,  -1],
#         [ 30,  -1,  -1,  28],
#         [ -1,  29,  -1,  28],
#         [ 32,  28,  -1,  -1],
#         [ 33,  31,  -1,  -1],
#         [ 34,  32,  -1,  -1],
#         [ 35,  33,  -1,  -1],
#         [ 36,  34,  -1,  -1],
#         [ 38,  35,  37,  -1],
#         [ -1,  -1,  -1,  36],
#         [ 41,  36,  39,  -1],
#         [ 40,  -1,  -1,  38],
#         [ -1,  39,  -1,  38],
#         [ 43,  38,  42,  -1],
#         [ -1,  -1,  -1,  41],
#         [ 44,  41,  -1,  -1],
#         [ 51,  43,  45,  -1],
#         [ 46,  -1,  -1,  44],
#         [ 47,  45,  -1,  44],
#         [ 48,  46,  -1,  44],
#         [ 49,  47,  -1,  44],
#         [ 50,  48,  -1,  44],
#         [ -1,  49,  -1,  44],
#         [ 53,  44,  52,  -1],
#         [ -1,  -1,  -1,  51],
#         [ 55,  51,  54,  -1],
#         [ -1,  -1,  -1,  53],
#         [ 56,  53,  -1,  -1],
#         [ 57,  55,  -1,  -1],
#         [ 59,  56,  58,  -1],
#         [ -1,  -1,  -1,  57],
#         [ 61,  57,  60,  -1],
#         [ -1,  -1,  -1,  59],
#         [ 65,  59,  62,  -1],
#         [ 63,  -1,  -1,  61],
#         [ 64,  62,  -1,  61],
#         [ -1,  63,  -1,  61],
#         [ 78,  61,  66,  -1],
#         [ 67,  -1,  -1,  65],
#         [ 68,  66,  -1,  65],
#         [ 69,  67,  -1,  65],
#         [ 70,  68,  -1,  65],
#         [ 71,  69,  -1,  65],
#         [ 72,  70,  -1,  65],
#         [ 73,  71,  -1,  65],
#         [ 74,  72,  -1,  65],
#         [ 75,  73,  -1,  65],
#         [ 76,  74,  -1,  65],
#         [ 77,  75,  -1,  65],
#         [ -1,  76,  -1,  65],
#         [ 79,  65,  -1,  -1],
#         [ 80,  78,  -1,  -1],
#         [ 83,  79,  81,  -1],
#         [ 82,  -1,  -1,  80],
#         [ -1,  81,  -1,  80],
#         [ 84,  80,  -1,  -1],
#         [ 85,  83,  -1,  -1],
#         [ 86,  84,  -1,  -1],
#         [ 89,  85,  87,  -1],
#         [ 88,  -1,  -1,  86],
#         [ -1,  87,  -1,  86],
#         [100,  86,  90,  -1],
#         [ 91,  -1,  -1,  89],
#         [ 92,  90,  -1,  89],
#         [ 93,  91,  -1,  89],
#         [ 94,  92,  -1,  89],
#         [ 95,  93,  -1,  89],
#         [ 96,  94,  -1,  89],
#         [ 97,  95,  -1,  89],
#         [ 98,  96,  -1,  89],
#         [ 99,  97,  -1,  89],
#         [ -1,  98,  -1,  89],
#         [103,  89, 101,  -1],
#         [102,  -1,  -1, 100],
#         [ -1, 101,  -1, 100],
#         [112, 100, 104,  -1],
#         [105,  -1,  -1, 103],
#         [106, 104,  -1, 103],
#         [107, 105,  -1, 103],
#         [108, 106,  -1, 103],
#         [109, 107,  -1, 103],
#         [110, 108,  -1, 103],
#         [111, 109,  -1, 103],
#         [ -1, 110,  -1, 103],
#         [125, 103, 113,  -1],
#         [114,  -1,  -1, 112],
#         [115, 113,  -1, 112],
#         [116, 114,  -1, 112],
#         [117, 115,  -1, 112],
#         [118, 116,  -1, 112],
#         [119, 117,  -1, 112],
#         [120, 118,  -1, 112],
#         [121, 119,  -1, 112],
#         [122, 120,  -1, 112],
#         [123, 121,  -1, 112],
#         [124, 122,  -1, 112],
#         [ -1, 123,  -1, 112],
#         [126, 112,  -1,  -1],
#         [128, 125, 127,  -1],
#         [ -1,  -1,  -1, 126],
#         [129, 126,  -1,  -1],
#         [132, 128, 130,  -1],
#         [131,  -1,  -1, 129],
#         [ -1, 130,  -1, 129],
#         [133, 129,  -1,  -1],
#         [144, 132, 134,  -1],
#         [135,  -1,  -1, 133],
#         [136, 134,  -1, 133],
#         [137, 135,  -1, 133],
#         [138, 136,  -1, 133],
#         [139, 137,  -1, 133],
#         [140, 138,  -1, 133],
#         [141, 139,  -1, 133],
#         [142, 140,  -1, 133],
#         [143, 141,  -1, 133],
#         [ -1, 142,  -1, 133],
#         [145, 133,  -1,  -1],
#         [146, 144,  -1,  -1],
#         [147, 145,  -1,  -1],
#         [148, 146,  -1,  -1],
#         [156, 147, 149,  -1],
#         [150,  -1,  -1, 148],
#         [151, 149,  -1, 148],
#         [152, 150,  -1, 148],
#         [153, 151,  -1, 148],
#         [154, 152,  -1, 148],
#         [155, 153,  -1, 148],
#         [ -1, 154,  -1, 148],
#         [ -1, 148, 157,  -1],
#         [ -1,  -1,  -1, 156]]], dtype=int32))

# %%
for path in paths[10:20]:
    img = cv2.imread(path)
    mask = np.zeros(img.shape[:2],np.uint8)
    bgdModel = np.zeros((1,65),np.float64)
    fgdModel = np.zeros((1,65),np.float64)
    rect = (20,20,170,290)
    cv2.grabCut(img,mask,rect,bgdModel,fgdModel,5,cv2.GC_INIT_WITH_RECT)
    mask2 = np.where((mask==2)|(mask==0),0,1).astype('uint8')
    img = img*mask2[:,:,np.newaxis]
    img[img>np.mean(img[img>10])]=255
    plt.imshow(img)
    plt.show()
