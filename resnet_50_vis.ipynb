# %% [markdown]
# # CPU

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import os

pp_time=np.load(os.path.join('benchmarks', 'resnet', 'cpu', 'pp_time.npy'))
p_time=np.load(os.path.join('benchmarks', 'resnet', 'cpu', 'p_time.npy'))
t_time=np.load(os.path.join('benchmarks', 'resnet', 'cpu', 't_time.npy'))

print('-------------FOR CPU---------')

print('-------------For Inference-------------')
print(f'Total Number of Images : {len(p_time)}')
print(f'Max Inference Time is : {round(np.max(p_time[1:]), 6) * 1000} msecs')
print(f'Min Inference Time is : {round(np.min(p_time[1:]), 6) * 1000} msecs')
print(f'Average Inference Time is : {round(np.average(p_time[1:]), 6) * 1000} msecs')
print(f'Mean Inference Time is : {round(np.mean(p_time[1:]), 6) * 1000} msecs')

plt.plot(p_time[150:300])
plt.ylabel('Time in secs')
plt.xlabel('Iterations')
plt.show()
# Out:
# -------------FOR CPU---------
# -------------For Inference-------------
# Total Number of Images : 1768000 msecs
# Max Inference Time is : 132.374 msecs
# Min Inference Time is : 116.075 msecs
# Average Inference Time is : 119.603 msecs
# Mean Inference Time is : 119.603 msecs

# %%
print('------------For Preprocessing----------')
print(f'Total Number of Images : {len(pp_time)}')
print(f'Max Preprocessing Time is : {round(np.max(pp_time[1:]), 6) *1000} msecs')
print(f'Min Preprocessing Time is : {round(np.min(pp_time[1:]), 6) *1000} msecs')
print(f'Average v Time is : {round(np.average(pp_time[1:]), 6) *1000} msecs')
print(f'Mean Preprocessing Time is : {round(np.mean(pp_time[1:]), 6) * 1000} msecs')

plt.plot(pp_time[150:300])
plt.ylabel('Time in secs')
plt.xlabel('Iterations')
plt.show()
# Out:
# ------------For Preprocessing----------
# Total Number of Images : 1768
# Max Preprocessing Time is : 2.488 msecs
# Min Preprocessing Time is : 1.655 msecs
# Average v Time is : 1.693 msecs
# Mean Preprocessing Time is : 1.693 msecs

# %%
print('----------Total Time-----------')
print(f'Total Number of Images : {len(t_time)}')
print(f'Max Time is : {round(np.max(t_time[1:]), 6) * 1000} msecs')
print(f'Min Time is : {round(np.min(t_time[1:]), 6) * 1000} msecs')
print(f'Average Time is : {round(np.average(t_time[1:]), 6) * 1000} msecs')
print(f'Average Time is : {round(np.mean(t_time[1:]), 6) * 1000} msecs')

plt.plot(t_time[150:300])
plt.ylabel('Time in secs')
plt.xlabel('Iterations')
plt.show()
# Out:
# ----------Total Time-----------
# Total Number of Images : 1768
# Max Time is : 134.077 msecs
# Min Time is : 117.774 msecs
# Average Time is : 121.298 msecs
# Average Time is : 121.298 msecs

# %% [markdown]
# # GPU

# %%
pp_time=np.load(os.path.join('benchmarks', 'resnet', 'gpu', 'pp_time.npy'))
p_time=np.load(os.path.join('benchmarks', 'resnet', 'gpu', 'p_time.npy'))
t_time=np.load(os.path.join('benchmarks', 'resnet', 'gpu', 't_time.npy'))

print('-------------FOR GPU---------')

print('-------------For Inference-------------')
print(f'Total Number of Images : {round(len(p_time), 6) * 1000} msecs')
print(f'Max Inference Time is : {round(np.max(p_time[1:]), 6) * 1000} msecs')
print(f'Min Inference Time is : {round(np.min(p_time[1:]), 6) * 1000} msecs')
print(f'Average Inference Time is : {round(np.average(p_time[1:]), 6) * 1000} msecs')
print(f'Mean Inference Time is : {round(np.mean(p_time[1:]), 6) * 1000} msecs')

plt.plot(p_time[150:300])
plt.ylabel('Time in secs')
plt.xlabel('Iterations')
plt.show()
# Out:
# -------------FOR GPU---------
# -------------For Inference-------------
# Total Number of Images : 1768000 msecs
# Max Inference Time is : 10.931 msecs
# Min Inference Time is : 9.593 msecs
# Average Inference Time is : 9.84 msecs
# Mean Inference Time is : 9.84 msecs

# %%
print('------------For Preprocessing----------')
print(f'Total Number of Images : {len(pp_time)}')
print(f'Max Preprocessing Time is : {np.max(pp_time[1:])}')
print(f'Min Preprocessing Time is : {round(np.min(pp_time[1:]), 6) *1000} msecs')
print(f'Average v Time is : {round(np.average(pp_time[1:]), 6) *1000} msecs')
print(f'Mean Preprocessing Time is : {round(np.mean(pp_time[1:]), 6) * 1000} msecs')

plt.plot(pp_time[150:300])
plt.ylabel('Time in secs')
plt.xlabel('Iterations')
plt.show()
# Out:
# ------------For Preprocessing----------
# Total Number of Images : 1768
# Max Preprocessing Time is : 2.8649999999999998 msecs
# Min Preprocessing Time is : 1.553 msecs
# Average v Time is : 1.624 msecs
# Mean Preprocessing Time is : 1.624 msecs

# %%
print('----------Total Time-----------')
print(f'Total Number of Images : {len(t_time)}')
print(f'Max Time is : {round(np.max(t_time[1:]), 6) * 1000} msecs')
print(f'Min Time is : {round(np.min(t_time[1:]), 6) * 1000} msecs')
print(f'Average Time is : {round(np.average(t_time[1:]), 6) * 1000} msecs')
print(f'Average Time is : {round(np.mean(t_time[1:]), 6) * 1000} msecs')

plt.plot(t_time[150:300])
plt.ylabel('Time in secs')
plt.xlabel('Iterations')
plt.show()
# Out:
# ----------Total Time-----------
# Total Number of Images : 1768
# Max Time is : 13.437 msecs
# Min Time is : 11.180000000000001 msecs
# Average Time is : 11.465 msecs
# Average Time is : 11.465 msecs
