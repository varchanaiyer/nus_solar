# %% [markdown]
# # CPU

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import os

pp_time=np.load(os.path.join('..', 'benchmarks', 'mobilenet', 'cpu', 'pp_time.npy'))
p_time=np.load(os.path.join('..', 'benchmarks', 'mobilenet', 'cpu', 'p_time.npy'))
t_time=np.load(os.path.join('..', 'benchmarks', 'mobilenet', 'cpu', 't_time.npy'))

print('-------------FOR CPU---------')

print('-------------For Inference-------------')
print(f'Total Number of Images : {len(p_time)}')
print(f'Max Inference Time is : {round(np.max(p_time[1:]), 6) * 1000} msecs')
print(f'Min Inference Time is : {round(np.min(p_time[1:]), 6) * 1000} msecs')
print(f'Average Inference Time is : {round(np.average(p_time[1:]), 6) * 1000} msecs')
print(f'Mean Inference Time is : {round(np.mean(p_time[1:]), 6) * 1000} msecs')

plt.plot(p_time[150:300])
plt.ylabel('Time in secs')
plt.xlabel('Iterations')
plt.show()
# Out:
# -------------FOR CPU---------
# -------------For Inference-------------
# Total Number of Images : 1768000 msecs
# Max Inference Time is : 52.567 msecs
# Min Inference Time is : 42.164 msecs
# Average Inference Time is : 43.901999999999994 msecs
# Mean Inference Time is : 43.901999999999994 msecs

# %%
print('------------For Preprocessing----------')
print(f'Total Number of Images : {len(pp_time)}')
print(f'Max Preprocessing Time is : {round(np.max(pp_time[1:]), 6) *1000} msecs')
print(f'Min Preprocessing Time is : {round(np.min(pp_time[1:]), 6) *1000} msecs')
print(f'Average v Time is : {round(np.average(pp_time[1:]), 6) *1000} msecs')
print(f'Mean Preprocessing Time is : {round(np.mean(pp_time[1:]), 6) * 1000} msecs')

plt.plot(pp_time[150:300])
plt.ylabel('Time in secs')
plt.xlabel('Iterations')
plt.show()
# Out:
# ------------For Preprocessing----------
# Total Number of Images : 1768
# Max Preprocessing Time is : 2.0860000000000003 msecs
# Min Preprocessing Time is : 1.607 msecs
# Average v Time is : 1.646 msecs
# Mean Preprocessing Time is : 1.646 msecs

# %%
print('----------Total Time-----------')
print(f'Total Number of Images : {len(t_time)}')
print(f'Max Time is : {round(np.max(t_time[1:]), 6) * 1000} msecs')
print(f'Min Time is : {round(np.min(t_time[1:]), 6) * 1000} msecs')
print(f'Average Time is : {round(np.average(t_time[1:]), 6) * 1000} msecs')
print(f'Average Time is : {round(np.mean(t_time[1:]), 6) * 1000} msecs')

plt.plot(t_time[150:300])
plt.ylabel('Time in secs')
plt.xlabel('Iterations')
plt.show()
# Out:
# ----------Total Time-----------
# Total Number of Images : 1768
# Max Time is : 54.208 msecs
# Min Time is : 43.814 msecs
# Average Time is : 45.549 msecs
# Average Time is : 45.549 msecs

# %% [markdown]
# # GPU

# %%
pp_time=np.load(os.path.join('..', 'benchmarks', 'mobilenet', 'gpu', 'pp_time.npy'))
p_time=np.load(os.path.join('..', 'benchmarks', 'mobilenet', 'gpu', 'p_time.npy'))
t_time=np.load(os.path.join('..', 'benchmarks', 'mobilenet', 'gpu', 't_time.npy'))

print('-------------FOR GPU---------')

print('-------------For Inference-------------')
print(f'Total Number of Images : {len(p_time)}')
print(f'Max Inference Time is : {round(np.max(p_time[1:]), 6) * 1000} msecs')
print(f'Min Inference Time is : {round(np.min(p_time[1:]), 6) * 1000} msecs')
print(f'Average Inference Time is : {round(np.average(p_time[1:]), 6) * 1000} msecs')
print(f'Mean Inference Time is : {round(np.mean(p_time[1:]), 6) * 1000} msecs')

plt.plot(p_time[150:300])
plt.ylabel('Time in secs')
plt.xlabel('Iterations')
plt.show()
# Out:
# -------------FOR GPU---------
# -------------For Inference-------------
# Total Number of Images : 1768000 msecs
# Max Inference Time is : 4.9750000000000005 msecs
# Min Inference Time is : 3.561 msecs
# Average Inference Time is : 3.75 msecs
# Mean Inference Time is : 3.75 msecs

# %%
print('------------For Preprocessing----------')
print(f'Total Number of Images : {len(pp_time)}')
print(f'Max Preprocessing Time is : {round(np.max(pp_time[1:]), 6) *1000} msecs')
print(f'Min Preprocessing Time is : {round(np.min(pp_time[1:]), 6) *1000} msecs')
print(f'Average v Time is : {round(np.average(pp_time[1:]), 6) *1000} msecs')
print(f'Mean Preprocessing Time is : {round(np.mean(pp_time[1:]), 6) * 1000} msecs')

plt.plot(pp_time[150:300])
plt.ylabel('Time in secs')
plt.xlabel('Iterations')
plt.show()
# Out:
# ------------For Preprocessing----------
# Total Number of Images : 1768
# Max Preprocessing Time is : 2.5460000000000003 msecs
# Min Preprocessing Time is : 1.488 msecs
# Average v Time is : 1.581 msecs
# Mean Preprocessing Time is : 1.581 msecs

# %%
print('----------Total Time-----------')
print(f'Total Number of Images : {len(t_time)}')
print(f'Max Time is : {round(np.max(t_time[1:]), 6) * 1000} msecs')
print(f'Min Time is : {round(np.min(t_time[1:]), 6) * 1000} msecs')
print(f'Average Time is : {round(np.average(t_time[1:]), 6) * 1000} msecs')
print(f'Average Time is : {round(np.mean(t_time[1:]), 6) * 1000} msecs')

plt.plot(t_time[150:300])
plt.ylabel('Time in secs')
plt.xlabel('Iterations')
plt.show()
# Out:
# ----------Total Time-----------
# Total Number of Images : 1768
# Max Time is : 6.989999999999999 msecs
# Min Time is : 5.087000000000001 msecs
# Average Time is : 5.333 msecs
# Average Time is : 5.333 msecs
